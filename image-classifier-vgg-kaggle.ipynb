# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rockpaperscissors/README_rpc-cv-images.txt
# /kaggle/input/rockpaperscissors/paper/cQ0dBO3yHPohZ9U9.png
# /kaggle/input/rockpaperscissors/paper/jAh36hlZLpECSBHp.png
# /kaggle/input/rockpaperscissors/paper/QnjBVl6cFnyd2hVF.png
# /kaggle/input/rockpaperscissors/paper/dZh2VMRu9nRGHhYL.png
# /kaggle/input/rockpaperscissors/paper/SDQQfzHl47yNqA6K.png
# /kaggle/input/rockpaperscissors/paper/E10FR2TKbBsv9Hgm.png
# /kaggle/input/rockpaperscissors/paper/BoMfAmQYWtoiGHBV.png
# /kaggle/input/rockpaperscissors/paper/AfvIbTwxuG0q7Ij1.png
# /kaggle/input/rockpaperscissors/paper/41HC0VBlHSRhi0AG.png
# /kaggle/input/rockpaperscissors/paper/gpipGA62xfMjfr8O.png
# /kaggle/input/rockpaperscissors/paper/9rwmakEj6Wg1YQWW.png
# /kaggle/input/rockpaperscissors/paper/D3mbFhVy7zFkZEtV.png
# /kaggle/input/rockpaperscissors/paper/cuDzhxpWujBPgJmX.png
# /kaggle/input/rockpaperscissors/paper/5FVy5hSvZ9c0M2Y5.png
# /kaggle/input/rockpaperscissors/paper/4aWP3XumkgwZtqZ7.png
# /kaggle/input/rockpaperscissors/paper/aac4C8FFlVQw6aGM.png
# /kaggle/input/rockpaperscissors/paper/UqMn3TJPZRf0px46.png
# /kaggle/input/rockpaperscissors/paper/PwkqvoT0noMITNaF.png
# /kaggle/input/rockpaperscissors/paper/QKFJL22hutlivVGa.png
# /kaggle/input/rockpaperscissors/paper/vvM7nA8hZJD5b9CL.png
# /kaggle/input/rockpaperscissors/paper/UCZlOkcylNYU2ylP.png
# /kaggle/input/rockpaperscissors/paper/pt2EHjG6vxV6Hjmf.png
# /kaggle/input/rockpaperscissors/paper/QLXEsveWG3vywKfy.png
# /kaggle/input/rockpaperscissors/paper/4484TuJc6AH7pDOG.png
# /kaggle/input/rockpaperscissors/paper/URj0hmH1Y9lNObL9.png
# /kaggle/input/rockpaperscissors/paper/0eqArS2GgsBeqgSn.png
# /kaggle/input/rockpaperscissors/paper/e6blzPfvGcrcHaKl.png
# /kaggle/input/rockpaperscissors/paper/zz1yffW197uYO6DI.png
# /kaggle/input/rockpaperscissors/paper/52nvTykEONIdmqQI.png
# /kaggle/input/rockpaperscissors/paper/BI9YnLkJ5wFZe6w8.png
# /kaggle/input/rockpaperscissors/paper/M4h0o8DAzyOpmgSM.png
# /kaggle/input/rockpaperscissors/paper/GelC88IvDZoRejHp.png
# /kaggle/input/rockpaperscissors/paper/Su03KsBNHrCVUXli.png
# /kaggle/input/rockpaperscissors/paper/DDHIkmyeaJPV7k0A.png
# /kaggle/input/rockpaperscissors/paper/9RmM1chbNsDKXXlg.png
# /kaggle/input/rockpaperscissors/paper/OhkFvTOiBqphyG0I.png
# /kaggle/input/rockpaperscissors/paper/TYjJigXjEyiVntzx.png
# /kaggle/input/rockpaperscissors/paper/k5n1w4gdm1G27rDk.png
# /kaggle/input/rockpaperscissors/paper/aJeRqPY3UVBErDTY.png
# /kaggle/input/rockpaperscissors/paper/MmzlgKI366LYX3fe.png
# /kaggle/input/rockpaperscissors/paper/6OhEpnz0QxBCfbXE.png
# /kaggle/input/rockpaperscissors/paper/wKiW95hiPu8zQhwV.png
# /kaggle/input/rockpaperscissors/paper/V9v5VHsYgQOVnzo2.png
# /kaggle/input/rockpaperscissors/paper/QCHltvmva5vmGrPo.png
# /kaggle/input/rockpaperscissors/paper/45ho1tx7W1LZB0DU.png
# /kaggle/input/rockpaperscissors/paper/3sKeYzYsjbWQVhc4.png
# /kaggle/input/rockpaperscissors/paper/OJpDyt2u6zzfoVP0.png
# /kaggle/input/rockpaperscissors/paper/rDfjA9TE0tYqzT21.png
# /kaggle/input/rockpaperscissors/paper/1uoW7QcH2qAgCTxv.png
# /kaggle/input/rockpaperscissors/paper/2PAcPusQ59xIMfiw.png
# /kaggle/input/rockpaperscissors/paper/t3gTGwl94iLuZL1k.png
# /kaggle/input/rockpaperscissors/paper/lGIPlKIVgwrDC17U.png
# /kaggle/input/rockpaperscissors/paper/4Pir885YNPXiRs0R.png
# /kaggle/input/rockpaperscissors/paper/bPTh8OjfiaJfzdcw.png
# /kaggle/input/rockpaperscissors/paper/OSEIPDjPzHw3gKjc.png
# /kaggle/input/rockpaperscissors/paper/B9PzXQbhzehhxFRN.png
# /kaggle/input/rockpaperscissors/paper/389udM70tLrMVL5H.png
# /kaggle/input/rockpaperscissors/paper/mWtDBJ2pprz96x22.png
# /kaggle/input/rockpaperscissors/paper/Om6b4BvZS49QNNFV.png
# /kaggle/input/rockpaperscissors/paper/68QZtdP6UaIcIE55.png
# /kaggle/input/rockpaperscissors/paper/nsbCG572TtIVkjKn.png
# /kaggle/input/rockpaperscissors/paper/7IYZ788SAadhvemj.png
# /kaggle/input/rockpaperscissors/paper/4bkmUMq0wOXElBIl.png
# /kaggle/input/rockpaperscissors/paper/KAoLE5XBuwjmtKj2.png
# /kaggle/input/rockpaperscissors/paper/b15QGB4XPECDemV5.png
# /kaggle/input/rockpaperscissors/paper/Eq9tohFHMpYXWQZH.png
# /kaggle/input/rockpaperscissors/paper/VrhvQlf5Yz5mAt7Y.png
# /kaggle/input/rockpaperscissors/paper/xha8stYdUnt02zKI.png
# /kaggle/input/rockpaperscissors/paper/ATs4aFUIODixPnMI.png
# /kaggle/input/rockpaperscissors/paper/ldGrLw1rlUq1nHuw.png
# /kaggle/input/rockpaperscissors/paper/Y7DDimLAYeU323au.png
# /kaggle/input/rockpaperscissors/paper/MLURv7NBoSPK4f1h.png
# /kaggle/input/rockpaperscissors/paper/StyclBeCFwYGuttl.png
# /kaggle/input/rockpaperscissors/paper/eASnEW16rlMUPMf3.png
# /kaggle/input/rockpaperscissors/paper/hUDN2qXDxjoGBWqu.png
# /kaggle/input/rockpaperscissors/paper/8X1BUL9w2OMExPy5.png
# /kaggle/input/rockpaperscissors/paper/af6U4DsLPicCZcED.png
# /kaggle/input/rockpaperscissors/paper/H8cGdqeAOdIyIMO5.png
# /kaggle/input/rockpaperscissors/paper/LEA78quc0fi2hq9W.png
# /kaggle/input/rockpaperscissors/paper/UQIJiOYi6zCaIeue.png
# /kaggle/input/rockpaperscissors/paper/Httje79JB2p6ePf0.png
# /kaggle/input/rockpaperscissors/paper/DE5gewqrqzSaVsdI.png
# /kaggle/input/rockpaperscissors/paper/XNUalPNmCkHhYk1i.png
# /kaggle/input/rockpaperscissors/paper/xJAZ3PewpLYs4ogR.png
# /kaggle/input/rockpaperscissors/paper/prCirglnpqZ4KRmM.png
# /kaggle/input/rockpaperscissors/paper/zru6yFR3dqc3SymW.png
# /kaggle/input/rockpaperscissors/paper/XnvU9UjrhVwfnSgj.png
# /kaggle/input/rockpaperscissors/paper/PLvidx6rZDuRENbv.png
# /kaggle/input/rockpaperscissors/paper/SjE9MULuPPnbplHT.png
# /kaggle/input/rockpaperscissors/paper/0Uomd0HvOB33m47I.png
# /kaggle/input/rockpaperscissors/paper/Uok6jb9ObZxSWCDu.png
# /kaggle/input/rockpaperscissors/paper/90GH8JQWUw9PUnlA.png
# /kaggle/input/rockpaperscissors/paper/9OyGmAsWD5Ie6QIa.png
# /kaggle/input/rockpaperscissors/paper/yM5JZ5J4uLeYIGOO.png
# /kaggle/input/rockpaperscissors/paper/LYirpnRmbCGN6T7O.png
# /kaggle/input/rockpaperscissors/paper/Klcu8qBjVs676hic.png
# /kaggle/input/rockpaperscissors/paper/EJ7cNnnea5yCEaOd.png
# /kaggle/input/rockpaperscissors/paper/Mq8Ym2axOJVIthiP.png
# /kaggle/input/rockpaperscissors/paper/WejRez1oUWm5lhuw.png
# /kaggle/input/rockpaperscissors/paper/nnf5jELXQuneoejn.png
# /kaggle/input/rockpaperscissors/paper/tV2VtZHsIL8Gj4TC.png
# /kaggle/input/rockpaperscissors/paper/lhr6oNI2jMsi0Z6A.png
# /kaggle/input/rockpaperscissors/paper/pUCjvjdpH5HSaWxl.png
# /kaggle/input/rockpaperscissors/paper/hu3OxByp0O4KCJft.png
# /kaggle/input/rockpaperscissors/paper/ZULuRlvYzTJM8jC3.png
# /kaggle/input/rockpaperscissors/paper/755DbuyE4rf2oGPA.png
# /kaggle/input/rockpaperscissors/paper/eBU0DmyWZu3WLjSO.png
# /kaggle/input/rockpaperscissors/paper/1yeoLbmp4alVOtFv.png
# /kaggle/input/rockpaperscissors/paper/LkNkNVjTRm5Gr9NQ.png
# /kaggle/input/rockpaperscissors/paper/UOW45qbyvti8nBHV.png
# /kaggle/input/rockpaperscissors/paper/C5LDaiOquQm9mDVH.png
# /kaggle/input/rockpaperscissors/paper/aOiWbMZF8BhxwLTs.png
# /kaggle/input/rockpaperscissors/paper/xioDLxSWnSZ5sDbQ.png
# /kaggle/input/rockpaperscissors/paper/5jcXrtjEVtQwI0Wa.png
# /kaggle/input/rockpaperscissors/paper/MKnNPdRtHfgr6ZbI.png
# /kaggle/input/rockpaperscissors/paper/y9DoLrI4Hlh2EUts.png
# /kaggle/input/rockpaperscissors/paper/QqPSoi6Vj2Vbua3V.png
# /kaggle/input/rockpaperscissors/paper/Di7hVJMSS3DzbSTi.png
# /kaggle/input/rockpaperscissors/paper/X5YjuJk3mrupKDrG.png
# /kaggle/input/rockpaperscissors/paper/Qbn4RJqessetWPHR.png
# /kaggle/input/rockpaperscissors/paper/MBCdeYSw1CGsIlHf.png
# /kaggle/input/rockpaperscissors/paper/6NzgMmSELzk3WtZh.png
# /kaggle/input/rockpaperscissors/paper/djVVgBL6PqTdtr6l.png
# /kaggle/input/rockpaperscissors/paper/XQihGnpPBb3DucOm.png
# /kaggle/input/rockpaperscissors/paper/3MMu7EXUtM6aEtXU.png
# /kaggle/input/rockpaperscissors/paper/q35FqG8h9VCDbQ1J.png
# /kaggle/input/rockpaperscissors/paper/CHf3O6SDtuPbbD0s.png
# /kaggle/input/rockpaperscissors/paper/aw7H9dMuThRnO74k.png
# /kaggle/input/rockpaperscissors/paper/2SldJqjiZwIVPef9.png
# /kaggle/input/rockpaperscissors/paper/dIg7Ds4xEzk0pyWZ.png
# /kaggle/input/rockpaperscissors/paper/qQim08vMQ6OUCtbR.png
# /kaggle/input/rockpaperscissors/paper/ZFMh222FMJzr0yLD.png
# /kaggle/input/rockpaperscissors/paper/g028Qv0lVlEbKi1q.png
# /kaggle/input/rockpaperscissors/paper/eLNpUj2AZ1h4Mrxu.png
# /kaggle/input/rockpaperscissors/paper/hCPYo6pBGExadl5o.png
# /kaggle/input/rockpaperscissors/paper/n1H2YStjFsCwmlYz.png
# /kaggle/input/rockpaperscissors/paper/atICt4otp6p6h31G.png
# /kaggle/input/rockpaperscissors/paper/QWT9FOhLABPyKIUA.png
# /kaggle/input/rockpaperscissors/paper/5NsmQol0TP7h80bh.png
# /kaggle/input/rockpaperscissors/paper/4Bimc2E5E9jTh1Fh.png
# /kaggle/input/rockpaperscissors/paper/UJXhVbWUgUnzedxP.png
# /kaggle/input/rockpaperscissors/paper/KPJ371erJ0RUKNAX.png
# /kaggle/input/rockpaperscissors/paper/qtfGt3JjA0Orrg9v.png
# /kaggle/input/rockpaperscissors/paper/CnRjJejRPD3QmYTl.png
# /kaggle/input/rockpaperscissors/paper/Miw8prUoiVMVG2D4.png
# /kaggle/input/rockpaperscissors/paper/wdUfwC8IoQbVtqzR.png
# /kaggle/input/rockpaperscissors/paper/FltCm1ep2lcnsOYz.png
# /kaggle/input/rockpaperscissors/paper/KqCGmJ8WCrqE5Uvg.png
# /kaggle/input/rockpaperscissors/paper/K8WJMHr1iCttaMbB.png
# /kaggle/input/rockpaperscissors/paper/wQQCLOgW5qXxkwli.png
# /kaggle/input/rockpaperscissors/paper/oi2e7ny5y00NBLOx.png
# /kaggle/input/rockpaperscissors/paper/MnvVVMoqDmzrm5NJ.png
# /kaggle/input/rockpaperscissors/paper/tFuz8mF78pYT6hKS.png
# /kaggle/input/rockpaperscissors/paper/lqo55attrFxuKqlu.png
# /kaggle/input/rockpaperscissors/paper/9bQFlg61mt0akPoM.png
# /kaggle/input/rockpaperscissors/paper/a0CaFEDoDB7qeyhN.png
# /kaggle/input/rockpaperscissors/paper/a21pgCIQ9pl0Guv5.png
# /kaggle/input/rockpaperscissors/paper/RmJmYq6VCNrrvi2l.png
# /kaggle/input/rockpaperscissors/paper/ACUZLBMxCu3AWgUu.png
# /kaggle/input/rockpaperscissors/paper/ldG6HLXeY0KilKyr.png
# /kaggle/input/rockpaperscissors/paper/hHY3BbYoVFjLEsbd.png
# /kaggle/input/rockpaperscissors/paper/aKUFn8PEF7LP8BaX.png
# /kaggle/input/rockpaperscissors/paper/RJrQJX31bej6flMr.png
# /kaggle/input/rockpaperscissors/paper/73UfZ8Dwj0OB66IV.png
# /kaggle/input/rockpaperscissors/paper/IKy6sz5i68TYNJH6.png
# /kaggle/input/rockpaperscissors/paper/ObnNNP8S6dH3IxIS.png
# /kaggle/input/rockpaperscissors/paper/BTG0fjXM09DyD4sh.png
# /kaggle/input/rockpaperscissors/paper/Mv6oOH192gse3oZA.png
# /kaggle/input/rockpaperscissors/paper/BH9zAUdmmjlfXwtS.png
# /kaggle/input/rockpaperscissors/paper/7v943QrV87m1Fx5U.png
# /kaggle/input/rockpaperscissors/paper/coKLsdqkvkYUv247.png
# /kaggle/input/rockpaperscissors/paper/pHx4pvFv4zXPDI1w.png
# /kaggle/input/rockpaperscissors/paper/1oKnUgV2CdCaQUUX.png
# /kaggle/input/rockpaperscissors/paper/zQvuYPyUR7gXdqXE.png
# /kaggle/input/rockpaperscissors/paper/hxUxn67g42jOHGHi.png
# /kaggle/input/rockpaperscissors/paper/BbOoLEGslGMBu7sj.png
# /kaggle/input/rockpaperscissors/paper/tsfjaR5pzLN4vfRW.png
# /kaggle/input/rockpaperscissors/paper/neo7ALjpzKdzVCj1.png
# /kaggle/input/rockpaperscissors/paper/raSxG3GjqMrYHvgW.png
# /kaggle/input/rockpaperscissors/paper/B9WSmSgclFPB3TOL.png
# /kaggle/input/rockpaperscissors/paper/3tNHP8R9YHru011u.png
# /kaggle/input/rockpaperscissors/paper/YnANqAVHDOylhBls.png
# /kaggle/input/rockpaperscissors/paper/BLqL31aC5YLmx3uF.png
# /kaggle/input/rockpaperscissors/paper/5eRezaxzYX8Canq0.png
# /kaggle/input/rockpaperscissors/paper/N3RjXoHuCkTs2Prd.png
# /kaggle/input/rockpaperscissors/paper/NS5CJKNsJa9jr5j4.png
# /kaggle/input/rockpaperscissors/paper/N4D5tleMLbP1Au5D.png
# /kaggle/input/rockpaperscissors/paper/yB11HwUEuYHhVlKo.png
# /kaggle/input/rockpaperscissors/paper/n10pI9JDPyeM0P73.png
# /kaggle/input/rockpaperscissors/paper/9Dto1OCNf5wjYimE.png
# /kaggle/input/rockpaperscissors/paper/qbWKhamyFLSmXCgZ.png
# /kaggle/input/rockpaperscissors/paper/CxcQ3XRBjkkmZ9b8.png
# /kaggle/input/rockpaperscissors/paper/nSfRj8Sp6S0GsMVm.png
# /kaggle/input/rockpaperscissors/paper/N5JmBjeptZ3hK3EK.png
# /kaggle/input/rockpaperscissors/paper/dftjUImANb0Q9pMA.png
# /kaggle/input/rockpaperscissors/paper/0vugygEjxQJPr9yz.png
# /kaggle/input/rockpaperscissors/paper/JOsGCJTsKvKGNHN1.png
# /kaggle/input/rockpaperscissors/paper/xR8mRBEdYAbokAEk.png
# /kaggle/input/rockpaperscissors/paper/5Iz9WPYz1C3PKWxj.png
# /kaggle/input/rockpaperscissors/paper/JsryGUQahbbNkrlP.png
# /kaggle/input/rockpaperscissors/paper/0RA9rcrv8iVvuDDU.png
# /kaggle/input/rockpaperscissors/paper/dZxpgHYRuQNv7T7A.png
# /kaggle/input/rockpaperscissors/paper/Y0XtXW0pn979O6KK.png
# /kaggle/input/rockpaperscissors/paper/Wcg4nsnlWrhxgyJg.png
# /kaggle/input/rockpaperscissors/paper/HTETrKtTEB31pvsK.png
# /kaggle/input/rockpaperscissors/paper/4Fxr7klOIfijCpio.png
# /kaggle/input/rockpaperscissors/paper/QQksMNb2czxqfTF8.png
# /kaggle/input/rockpaperscissors/paper/RlpqfQnTgM6AxUNs.png
# /kaggle/input/rockpaperscissors/paper/nGxiCAryWhadfu7W.png
# /kaggle/input/rockpaperscissors/paper/UJdZdj6nyFRHVFEg.png
# /kaggle/input/rockpaperscissors/paper/O4H6QPX8bdwNiIie.png
# /kaggle/input/rockpaperscissors/paper/4dpYSXpjYbiH9MSq.png
# /kaggle/input/rockpaperscissors/paper/HbBcQItQ6d5yMDqL.png
# /kaggle/input/rockpaperscissors/paper/7Px9USAD7J56woB0.png
# /kaggle/input/rockpaperscissors/paper/2tDgPZGqbrw95j39.png
# /kaggle/input/rockpaperscissors/paper/cf9L4KKsfsFpRrYA.png
# /kaggle/input/rockpaperscissors/paper/to1CYeerlgzyJIeO.png
# /kaggle/input/rockpaperscissors/paper/0zKU6wEhT2cDe9j0.png
# /kaggle/input/rockpaperscissors/paper/cI2tl5vM2koXZPfG.png
# /kaggle/input/rockpaperscissors/paper/3K6a8bG8j1YTH1l0.png
# /kaggle/input/rockpaperscissors/paper/LAhqdrhPNg3ZLxpr.png
# /kaggle/input/rockpaperscissors/paper/r9sXHEyVJVCtshSA.png
# /kaggle/input/rockpaperscissors/paper/NLwrHPTaiNSMjHLX.png
# /kaggle/input/rockpaperscissors/paper/zBMp6VflTDyfCqa6.png
# /kaggle/input/rockpaperscissors/paper/m4BUXxtLrhnsSUJ2.png
# /kaggle/input/rockpaperscissors/paper/nOTm1e00MAJxvpwp.png
# /kaggle/input/rockpaperscissors/paper/SoqluLecSTBcuyoS.png
# /kaggle/input/rockpaperscissors/paper/eCZWzeGkpX6rdizo.png
# /kaggle/input/rockpaperscissors/paper/0a3UtNzl5Ll3sq8K.png
# /kaggle/input/rockpaperscissors/paper/P0BIztnCzZ3StLD1.png
# /kaggle/input/rockpaperscissors/paper/tfMCcOsRUhEJZF6I.png
# /kaggle/input/rockpaperscissors/paper/LhgH8QOKfA5xu287.png
# /kaggle/input/rockpaperscissors/paper/s73bLQf6K0lw4RDJ.png
# /kaggle/input/rockpaperscissors/paper/NKNFgMn2Ik3Y9XuX.png
# /kaggle/input/rockpaperscissors/paper/JApmimWQx0vFx1qw.png
# /kaggle/input/rockpaperscissors/paper/R7y8PxDKzaAd0uUQ.png
# /kaggle/input/rockpaperscissors/paper/qGf97ZWPmGYzlTpo.png
# /kaggle/input/rockpaperscissors/paper/IQsx834hZ2POqopO.png
# /kaggle/input/rockpaperscissors/paper/tW1oIjn0hlGLToAY.png
# /kaggle/input/rockpaperscissors/paper/B08mrGoODd5gGTvu.png
# /kaggle/input/rockpaperscissors/paper/DOuDihjhzIuZ2skd.png
# /kaggle/input/rockpaperscissors/paper/oLcpS2BYyqZLBj9P.png
# /kaggle/input/rockpaperscissors/paper/bWjObTeNghy8Z1zE.png
# /kaggle/input/rockpaperscissors/paper/knWd03lNhoAUPdKX.png
# /kaggle/input/rockpaperscissors/paper/2UKnsncgPodQLOFR.png
# /kaggle/input/rockpaperscissors/paper/wBuXrsjeqMn4ZXdn.png
# /kaggle/input/rockpaperscissors/paper/Vly5xEFupx36kCcd.png
# /kaggle/input/rockpaperscissors/paper/Qx31hf6YWyFs6Mu7.png
# /kaggle/input/rockpaperscissors/paper/rSRKkten7Ffx6bEj.png
# /kaggle/input/rockpaperscissors/paper/4ZoU4nouZzb9G2MI.png
# /kaggle/input/rockpaperscissors/paper/7NyxZyxSJ1gphzUE.png
# /kaggle/input/rockpaperscissors/paper/7PSJU8kbZf8S6FRW.png
# /kaggle/input/rockpaperscissors/paper/oJi50DvlvFg4wTio.png
# /kaggle/input/rockpaperscissors/paper/EJ42U85HcmJV7JVm.png
# /kaggle/input/rockpaperscissors/paper/iGiF1suI8wXP6A2r.png
# /kaggle/input/rockpaperscissors/paper/FxLuxwBp9Hw2th2O.png
# /kaggle/input/rockpaperscissors/paper/kVKp9kJji4urjoMs.png
# /kaggle/input/rockpaperscissors/paper/mV9vc1ITH1PrrbF8.png
# /kaggle/input/rockpaperscissors/paper/khFWD3MPEKPitVyA.png
# /kaggle/input/rockpaperscissors/paper/XPvzu0bXUw8THjbU.png
# /kaggle/input/rockpaperscissors/paper/ePEd8TOzTgrGz5M2.png
# /kaggle/input/rockpaperscissors/paper/mZW0RUegJl9SM8ck.png
# /kaggle/input/rockpaperscissors/paper/orYuZ7NeWdENNt7D.png
# /kaggle/input/rockpaperscissors/paper/7L3Xke8iQBzywEPH.png
# /kaggle/input/rockpaperscissors/paper/JZ8KCFK6y0Zd87Xl.png
# /kaggle/input/rockpaperscissors/paper/3YvRoN0ZGuXVWEbh.png
# /kaggle/input/rockpaperscissors/paper/P1STllnKDD05zo29.png
# /kaggle/input/rockpaperscissors/paper/RW8BP64V5NC04QWf.png
# /kaggle/input/rockpaperscissors/paper/n5NXfZTRonR4iOr0.png
# /kaggle/input/rockpaperscissors/paper/zXY93m62vUNIH4a0.png
# /kaggle/input/rockpaperscissors/paper/1yKjzquSvl9ShK7K.png
# /kaggle/input/rockpaperscissors/paper/tlZ31lJJt1OhSr0a.png
# /kaggle/input/rockpaperscissors/paper/ubb6xwgONJP3xBbv.png
# /kaggle/input/rockpaperscissors/paper/mK7Kqflg12vHFBEK.png
# /kaggle/input/rockpaperscissors/paper/8I8hrFbPPNz6qWeV.png
# /kaggle/input/rockpaperscissors/paper/veIFAtZUg4WYjn3N.png
# /kaggle/input/rockpaperscissors/paper/WVfwcOw6nXcg4xER.png
# /kaggle/input/rockpaperscissors/paper/qRNjm8INtwezm9Yd.png
# /kaggle/input/rockpaperscissors/paper/SsvKZDW23vRQMUtA.png
# /kaggle/input/rockpaperscissors/paper/Lq77eAG8OPaizwEd.png
# /kaggle/input/rockpaperscissors/paper/VstDOeRm7czrAOO9.png
# /kaggle/input/rockpaperscissors/paper/sZyZICXHv0ArIZFw.png
# /kaggle/input/rockpaperscissors/paper/cMbbpVIgFU95R4tO.png
# /kaggle/input/rockpaperscissors/paper/QVFB67Eza3BCNeRY.png
# /kaggle/input/rockpaperscissors/paper/W79peyAyfQqNP1vF.png
# /kaggle/input/rockpaperscissors/paper/vfKiFjWIK9JKHxLn.png
# /kaggle/input/rockpaperscissors/paper/tiS1ECooPwR5IvFK.png
# /kaggle/input/rockpaperscissors/paper/SPx9aUguwNqxqPVS.png
# /kaggle/input/rockpaperscissors/paper/zrZmvRbPtB57a4Vr.png
# /kaggle/input/rockpaperscissors/paper/nXOxF15xZFtfflkL.png
# /kaggle/input/rockpaperscissors/paper/IkSLcJtq4O6iBmE4.png
# /kaggle/input/rockpaperscissors/paper/rX4dcSySbz56p4dk.png
# /kaggle/input/rockpaperscissors/paper/8qhPJIViAhfZTJkA.png
# /kaggle/input/rockpaperscissors/paper/AjwddXm0ttm7Ts5J.png
# /kaggle/input/rockpaperscissors/paper/R2Hq3bL46kah8D9n.png
# /kaggle/input/rockpaperscissors/paper/mUqkjFi6NBsHR7tf.png
# /kaggle/input/rockpaperscissors/paper/LpASHQ03atiBeyRw.png
# /kaggle/input/rockpaperscissors/paper/d5FmD95HmhodiITj.png
# /kaggle/input/rockpaperscissors/paper/Tgy8eMKf7vZc4Eib.png
# /kaggle/input/rockpaperscissors/paper/gO7yxcP6H1vZ7lOe.png
# /kaggle/input/rockpaperscissors/paper/UN3iCDyiEIteIMdx.png
# /kaggle/input/rockpaperscissors/paper/jYSFgcG68qqavVn6.png
# /kaggle/input/rockpaperscissors/paper/eQaNnPaHwKsOJaYq.png
# /kaggle/input/rockpaperscissors/paper/QASICiZe79sFTXBz.png
# /kaggle/input/rockpaperscissors/paper/HQSUE6P23pvLctuy.png
# /kaggle/input/rockpaperscissors/paper/7I1fABs6SL1T4MNb.png
# /kaggle/input/rockpaperscissors/paper/p81Lb4bD6fEvkSQ0.png
# /kaggle/input/rockpaperscissors/paper/dDtRH0QF7IPSsasH.png
# /kaggle/input/rockpaperscissors/paper/K6IACWoiTOnGR9Np.png
# /kaggle/input/rockpaperscissors/paper/6wuALDd920vZ0qZE.png
# /kaggle/input/rockpaperscissors/paper/HuunhhoTMXTrST2Z.png
# /kaggle/input/rockpaperscissors/paper/1Dfw5FRlS4h60JPX.png
# /kaggle/input/rockpaperscissors/paper/ZGQV7rFVePreAdOe.png
# /kaggle/input/rockpaperscissors/paper/ehzdlf5B1HtVgpRs.png
# /kaggle/input/rockpaperscissors/paper/jaxChUvakWAN9eTs.png
# /kaggle/input/rockpaperscissors/paper/t2SdNfWDiXGLJPBA.png
# /kaggle/input/rockpaperscissors/paper/pwM1GeKjG7KE4i75.png
# /kaggle/input/rockpaperscissors/paper/wYsHIJDvNLDvn4m7.png
# /kaggle/input/rockpaperscissors/paper/Xr1e0JehAkRxNzTj.png
# /kaggle/input/rockpaperscissors/paper/HvQdmFU7Qzd4SSQ4.png
# /kaggle/input/rockpaperscissors/paper/FcIIjteQItMuIuRa.png
# /kaggle/input/rockpaperscissors/paper/FKhLHIIqEsYmoZxy.png
# /kaggle/input/rockpaperscissors/paper/QZtii0ogsjl6hxun.png
# /kaggle/input/rockpaperscissors/paper/ukOGooYiFOfJHNrx.png
# /kaggle/input/rockpaperscissors/paper/yPnREvUeAGYRKi7V.png
# /kaggle/input/rockpaperscissors/paper/7w91NsCtVzsPOSYB.png
# /kaggle/input/rockpaperscissors/paper/JlMP0YH6vhxWRMZz.png
# /kaggle/input/rockpaperscissors/paper/KAyKztBfGIWm4qN7.png
# /kaggle/input/rockpaperscissors/paper/vFCd43peE8nozYko.png
# /kaggle/input/rockpaperscissors/paper/BVfw3Er2AUBqREYJ.png
# /kaggle/input/rockpaperscissors/paper/UWq276y40jnVYaPC.png
# /kaggle/input/rockpaperscissors/paper/7Vor5Uo4DweXkpE7.png
# /kaggle/input/rockpaperscissors/paper/JUn3VuVCoOKC5Nv2.png
# /kaggle/input/rockpaperscissors/paper/ZjHU1M9wOwgrm7SX.png
# /kaggle/input/rockpaperscissors/paper/HkBUo9kQDJho4uor.png
# /kaggle/input/rockpaperscissors/paper/ZGLUqWHjarBly23b.png
# /kaggle/input/rockpaperscissors/paper/7fRLxoheLluOwCkp.png
# /kaggle/input/rockpaperscissors/paper/ngFDxBhhLQzs7JAH.png
# /kaggle/input/rockpaperscissors/paper/UuF8mRQ3FDM6fOmp.png
# /kaggle/input/rockpaperscissors/paper/TcybcTuKdMPA4xpT.png
# /kaggle/input/rockpaperscissors/paper/9qKKOliWXD7oDZOd.png
# /kaggle/input/rockpaperscissors/paper/DGR6Jkl5GJY9Sez0.png
# /kaggle/input/rockpaperscissors/paper/4IwJ2iL6pFz5ARWA.png
# /kaggle/input/rockpaperscissors/paper/znZ3UHvUM8ySVpDR.png
# /kaggle/input/rockpaperscissors/paper/5Cy2fFOaWMFwa5iu.png
# /kaggle/input/rockpaperscissors/paper/WUJ02oAbtzoPF4oo.png
# /kaggle/input/rockpaperscissors/paper/PTjpGk2rKf6mhx9z.png
# /kaggle/input/rockpaperscissors/paper/ywXiLajxMzhy7BST.png
# /kaggle/input/rockpaperscissors/paper/ul2wGK0NgJXs8mHv.png
# /kaggle/input/rockpaperscissors/paper/2IOsxsG8AaxntdJM.png
# /kaggle/input/rockpaperscissors/paper/3XEQ73XMn7zaww2T.png
# /kaggle/input/rockpaperscissors/paper/V7gDBwuUctk8myTw.png
# /kaggle/input/rockpaperscissors/paper/nvCwoV9k3ym5N0JA.png
# /kaggle/input/rockpaperscissors/paper/jCTsslbOLn04znvK.png
# /kaggle/input/rockpaperscissors/paper/VUx1G75w9CbeAJUx.png
# /kaggle/input/rockpaperscissors/paper/YaRk8v83K7BQmi5G.png
# /kaggle/input/rockpaperscissors/paper/oAvUHooYsSpFid0p.png
# /kaggle/input/rockpaperscissors/paper/9zfyVkUcku0qc4Gu.png
# /kaggle/input/rockpaperscissors/paper/zGty6p4zGTzRip73.png
# /kaggle/input/rockpaperscissors/paper/fCX7MPg0xO4QP2Mk.png
# /kaggle/input/rockpaperscissors/paper/dUDR2ViadkqS6EHf.png
# /kaggle/input/rockpaperscissors/paper/k9d5xaurp8JC9DXp.png
# /kaggle/input/rockpaperscissors/paper/Zo0eTAGaUb4ewSkf.png
# /kaggle/input/rockpaperscissors/paper/Y8kfG3f6KJa1YJPA.png
# /kaggle/input/rockpaperscissors/paper/cw7oAjQLSjDYZPXH.png
# /kaggle/input/rockpaperscissors/paper/RqdXcCyqmXMxSDxn.png
# /kaggle/input/rockpaperscissors/paper/5U8st2LCr9zLl5og.png
# /kaggle/input/rockpaperscissors/paper/2DQbLQfHlfrcATqi.png
# /kaggle/input/rockpaperscissors/paper/lb8kepfzcnutbQI1.png
# /kaggle/input/rockpaperscissors/paper/Je4YZuaXlY4KaAfQ.png
# /kaggle/input/rockpaperscissors/paper/XF9I4tnxCvI7XzIG.png
# /kaggle/input/rockpaperscissors/paper/9xyvz1JbPwNqtLgH.png
# /kaggle/input/rockpaperscissors/paper/XCoWpNiWscJm476F.png
# /kaggle/input/rockpaperscissors/paper/eCpHvcUt4r7A9xJE.png
# /kaggle/input/rockpaperscissors/paper/U2InMVDH10R24eOb.png
# /kaggle/input/rockpaperscissors/paper/wfpI2zfWOeQbwd1f.png
# /kaggle/input/rockpaperscissors/paper/Rxmuq5Y6dw22QESt.png
# /kaggle/input/rockpaperscissors/paper/Z4HE3jW7SMOonYFA.png
# /kaggle/input/rockpaperscissors/paper/C3j6RdTEo4jf6Cr4.png
# /kaggle/input/rockpaperscissors/paper/Dvamqz9JlSMySW1i.png
# /kaggle/input/rockpaperscissors/paper/C7zCG474LseZgn8o.png
# /kaggle/input/rockpaperscissors/paper/COmibsBioPBur0V9.png
# /kaggle/input/rockpaperscissors/paper/KJ77yLPN943SrPZW.png
# /kaggle/input/rockpaperscissors/paper/v6wOWeRyh3Sv5BXo.png
# /kaggle/input/rockpaperscissors/paper/yYba9sH9TlYCAtoo.png
# /kaggle/input/rockpaperscissors/paper/n8IzyztMwnfa5rjf.png
# /kaggle/input/rockpaperscissors/paper/SrSUeH255dybz2zi.png
# /kaggle/input/rockpaperscissors/paper/j8dvLhkeL92SpOGj.png
# /kaggle/input/rockpaperscissors/paper/CJ3BCSOVp8uzaPnY.png
# /kaggle/input/rockpaperscissors/paper/PbqPTUSB4HxBVDZZ.png
# /kaggle/input/rockpaperscissors/paper/W4QtOYoG8ThbcmsY.png
# /kaggle/input/rockpaperscissors/paper/qZX4Zcms0Ffpe8v7.png
# /kaggle/input/rockpaperscissors/paper/wytuIz48uLeDoGqz.png
# /kaggle/input/rockpaperscissors/paper/IXh9BTFQQ6AIaBpr.png
# /kaggle/input/rockpaperscissors/paper/1fKclJk4eBWOQSR1.png
# /kaggle/input/rockpaperscissors/paper/0cb6cVL8pkfi4wF6.png
# /kaggle/input/rockpaperscissors/paper/vPvoQzBR7Paf5Jml.png
# /kaggle/input/rockpaperscissors/paper/Ht08RX3DQCSdl9Sy.png
# /kaggle/input/rockpaperscissors/paper/yWLbGUHRsGx5ocE9.png
# /kaggle/input/rockpaperscissors/paper/i47BmmqwUa4y0jIP.png
# /kaggle/input/rockpaperscissors/paper/OMq2VJyb0KwtdwDc.png
# /kaggle/input/rockpaperscissors/paper/CpDMCILKUN2AUA1A.png
# /kaggle/input/rockpaperscissors/paper/2PiUTczN5Ez4VreF.png
# /kaggle/input/rockpaperscissors/paper/ZnuLAMdyI9xJCcKE.png
# /kaggle/input/rockpaperscissors/paper/v4pz2TAsHhtNtTAH.png
# /kaggle/input/rockpaperscissors/paper/UE6Ao0ZqJbQ1R1R5.png
# /kaggle/input/rockpaperscissors/paper/TlnoQ46NyW8oZV07.png
# /kaggle/input/rockpaperscissors/paper/YTZfr87ETKYNkQRN.png
# /kaggle/input/rockpaperscissors/paper/Cx9G4YyKPI9MPcqp.png
# /kaggle/input/rockpaperscissors/paper/8NNPWO3e2oNq8lg9.png
# /kaggle/input/rockpaperscissors/paper/e50cckZL8BKmqzjd.png
# /kaggle/input/rockpaperscissors/paper/Lmx5I567tGyQ9HYi.png
# /kaggle/input/rockpaperscissors/paper/B3dlyiRDulDJWOsW.png
# /kaggle/input/rockpaperscissors/paper/qC5sV6TzOBzyzW0p.png
# /kaggle/input/rockpaperscissors/paper/sak9CBkECbg1PSLz.png
# /kaggle/input/rockpaperscissors/paper/ejC8QIku5jrtci48.png
# /kaggle/input/rockpaperscissors/paper/L2S17RtFi8XXp6b8.png
# /kaggle/input/rockpaperscissors/paper/hH7jcOkAiHqNDWcy.png
# /kaggle/input/rockpaperscissors/paper/oBKuveyTYAhqtKSw.png
# /kaggle/input/rockpaperscissors/paper/AqNY2b7NX9Ce3CjZ.png
# /kaggle/input/rockpaperscissors/paper/B6dJfDThlXx80Uk6.png
# /kaggle/input/rockpaperscissors/paper/pYvpGm431tLNheln.png
# /kaggle/input/rockpaperscissors/paper/uoYuyEHvVLrOOmqW.png
# /kaggle/input/rockpaperscissors/paper/CrEzO2508GiIMFrx.png
# /kaggle/input/rockpaperscissors/paper/yaRRMcZS7JJ3xLK1.png
# /kaggle/input/rockpaperscissors/paper/a9SyLOjQZE4llCvX.png
# /kaggle/input/rockpaperscissors/paper/pMQfFsmXAu2xZuUv.png
# /kaggle/input/rockpaperscissors/paper/Ih5Z5Z3xFZ17IcZS.png
# /kaggle/input/rockpaperscissors/paper/fnbn7osMCGWmqHKZ.png
# /kaggle/input/rockpaperscissors/paper/74FZPuPPfVCwqHgO.png
# /kaggle/input/rockpaperscissors/paper/PaZSkEO4jbBp3Hz7.png
# /kaggle/input/rockpaperscissors/paper/pVCqrp8S6Ze3DAI8.png
# /kaggle/input/rockpaperscissors/paper/LqxEdPczGbYd9Zlu.png
# /kaggle/input/rockpaperscissors/paper/Ze6bn38U5XECyORF.png
# /kaggle/input/rockpaperscissors/paper/v1b7FBFD4ZbLJnhB.png
# /kaggle/input/rockpaperscissors/paper/E4TyifCgPm6OwcrY.png
# /kaggle/input/rockpaperscissors/paper/nmkNauqVsM2JUvok.png
# /kaggle/input/rockpaperscissors/paper/f423uSEl5slK7nbj.png
# /kaggle/input/rockpaperscissors/paper/A0Dgq561RAiluT9p.png
# /kaggle/input/rockpaperscissors/paper/bxn0wMR4QebqVl62.png
# /kaggle/input/rockpaperscissors/paper/FwR0aXsgOZ5KHDjH.png
# /kaggle/input/rockpaperscissors/paper/fjITlTb11LELvo3e.png
# /kaggle/input/rockpaperscissors/paper/6ycslJxTsTjZc5H2.png
# /kaggle/input/rockpaperscissors/paper/Z5ioSnqxnoCUixRW.png
# /kaggle/input/rockpaperscissors/paper/MLrUGD1graoSw2c5.png
# /kaggle/input/rockpaperscissors/paper/s4dtRIGK3emNyjrO.png
# /kaggle/input/rockpaperscissors/paper/2F8Ng7620ANA7tEK.png
# /kaggle/input/rockpaperscissors/paper/svY0FVnjij1nSJDK.png
# /kaggle/input/rockpaperscissors/paper/gFqfkMtX39sTkrSB.png
# /kaggle/input/rockpaperscissors/paper/bQO2dBIReHsgMCBi.png
# /kaggle/input/rockpaperscissors/paper/RQ78Zpf7uYHXCYcb.png
# /kaggle/input/rockpaperscissors/paper/Q8idpb4gCSAWs9YH.png
# /kaggle/input/rockpaperscissors/paper/p2UN3r1vWk57uVqX.png
# /kaggle/input/rockpaperscissors/paper/sDAWCwVlT2NFpEAf.png
# /kaggle/input/rockpaperscissors/paper/hfYfNNtqkFzF9BE4.png
# /kaggle/input/rockpaperscissors/paper/xsM5n0KOqwb5R58V.png
# /kaggle/input/rockpaperscissors/paper/SboHPaPEPBqkkTUX.png
# /kaggle/input/rockpaperscissors/paper/QCqvYDzuP0z3omox.png
# /kaggle/input/rockpaperscissors/paper/PDV8vSlSFdej3jNx.png
# /kaggle/input/rockpaperscissors/paper/NwbFl4nQqE5pm5PZ.png
# /kaggle/input/rockpaperscissors/paper/xJNBzdx479xjphEV.png
# /kaggle/input/rockpaperscissors/paper/CwFaCN3ykqwQ6KZV.png
# /kaggle/input/rockpaperscissors/paper/YkZMyyS9fJdKmL3F.png
# /kaggle/input/rockpaperscissors/paper/Z9vSGzBQ8YLOXQIX.png
# /kaggle/input/rockpaperscissors/paper/LI47bUY9rR60z73q.png
# /kaggle/input/rockpaperscissors/paper/ojF0xyUvkvV3iujz.png
# /kaggle/input/rockpaperscissors/paper/fYuJzeeHPzGwlGh0.png
# /kaggle/input/rockpaperscissors/paper/Nm8PHXHrGlZy0d6Q.png
# /kaggle/input/rockpaperscissors/paper/BqGdYFfhQ4sOU5Xl.png
# /kaggle/input/rockpaperscissors/paper/UHyVkisiFMmasl7b.png
# /kaggle/input/rockpaperscissors/paper/yUhvKMWrPQ9sJ78m.png
# /kaggle/input/rockpaperscissors/paper/G4QepYlFnpE8Zse4.png
# /kaggle/input/rockpaperscissors/paper/YrEfjld9tYk0b9m9.png
# /kaggle/input/rockpaperscissors/paper/JsrOSaR3txTRu3I9.png
# /kaggle/input/rockpaperscissors/paper/yfoLtt4c7Rzc5VOW.png
# /kaggle/input/rockpaperscissors/paper/qjNwQMtSzoZKXOGe.png
# /kaggle/input/rockpaperscissors/paper/kz9TBAHLFXGnHCiF.png
# /kaggle/input/rockpaperscissors/paper/eiiwN1DsKoIheMgz.png
# /kaggle/input/rockpaperscissors/paper/dF7Gvm0vgCJZofAW.png
# /kaggle/input/rockpaperscissors/paper/9WQaDoiIDC4zGPr8.png
# /kaggle/input/rockpaperscissors/paper/em91htnBohvtnG2e.png
# /kaggle/input/rockpaperscissors/paper/fSWSXO9fumLluiAF.png
# /kaggle/input/rockpaperscissors/paper/Lwd11NDu17odCiv7.png
# /kaggle/input/rockpaperscissors/paper/JDZ86cNk15r0NTi6.png
# /kaggle/input/rockpaperscissors/paper/5RvFm2PYoG18yIZO.png
# /kaggle/input/rockpaperscissors/paper/89dWYgfIZm624Pf6.png
# /kaggle/input/rockpaperscissors/paper/RtFKKjIDZ0zA0khp.png
# /kaggle/input/rockpaperscissors/paper/HYIh5ipF4bN1futQ.png
# /kaggle/input/rockpaperscissors/paper/pfyaiU10n2EvAwgw.png
# /kaggle/input/rockpaperscissors/paper/ueuECCtQxOjHF1ij.png
# /kaggle/input/rockpaperscissors/paper/DBriMZZSZtYea72l.png
# /kaggle/input/rockpaperscissors/paper/qsRQNgddFhV2Mlnn.png
# /kaggle/input/rockpaperscissors/paper/460WcktBwCAzsU0A.png
# /kaggle/input/rockpaperscissors/paper/r98ovEGxFpCnVnyy.png
# /kaggle/input/rockpaperscissors/paper/pW8TQWh9SoWh0HLE.png
# /kaggle/input/rockpaperscissors/paper/pPId4ocKjlcEVsXt.png
# /kaggle/input/rockpaperscissors/paper/vUtM1pR6f5ZdEn5a.png
# /kaggle/input/rockpaperscissors/paper/ZBA0HPVlxkCdle5v.png
# /kaggle/input/rockpaperscissors/paper/C9tAvywdtjDTnllg.png
# /kaggle/input/rockpaperscissors/paper/JKN8VKp7pfMEQdBZ.png
# /kaggle/input/rockpaperscissors/paper/eLBTZkvB4E951ml0.png
# /kaggle/input/rockpaperscissors/paper/OXA4uaaO7YUkxjSJ.png
# /kaggle/input/rockpaperscissors/paper/LrVULgPLsLsfdZ2z.png
# /kaggle/input/rockpaperscissors/paper/rrSpAVrlixKrTC1T.png
# /kaggle/input/rockpaperscissors/paper/X3iDu3E3UCW1w1Cd.png
# /kaggle/input/rockpaperscissors/paper/EuU83pQABhf4v0AF.png
# /kaggle/input/rockpaperscissors/paper/QVIiXr87PkeldzZM.png
# /kaggle/input/rockpaperscissors/paper/VFOCgVBUlL5Gp4Hh.png
# /kaggle/input/rockpaperscissors/paper/n9SDT7R9BSLRNCe1.png
# /kaggle/input/rockpaperscissors/paper/xhKyuxHPC3RnoLD0.png
# /kaggle/input/rockpaperscissors/paper/y2auZRkrUIi0wvd2.png
# /kaggle/input/rockpaperscissors/paper/HarpXSxVfoAJ9cFe.png
# /kaggle/input/rockpaperscissors/paper/HIo7Eax3OPP5MuXl.png
# /kaggle/input/rockpaperscissors/paper/1Frbe8cdOdkciOBg.png
# /kaggle/input/rockpaperscissors/paper/KOlOsNsrUdQonYpp.png
# /kaggle/input/rockpaperscissors/paper/dPSQ4TKPBJyjv6cH.png
# /kaggle/input/rockpaperscissors/paper/MKe2ciaSOmdDH1JK.png
# /kaggle/input/rockpaperscissors/paper/OdfDTwgPVdW9XbE7.png
# /kaggle/input/rockpaperscissors/paper/av2NxK494nd72Q13.png
# /kaggle/input/rockpaperscissors/paper/1jHtb93pI8f6pfKo.png
# /kaggle/input/rockpaperscissors/paper/byBLmTC0iWfnT7wo.png
# /kaggle/input/rockpaperscissors/paper/Arbkrts1pXpDNgFV.png
# /kaggle/input/rockpaperscissors/paper/mugG8B1m5Ra2aRgZ.png
# /kaggle/input/rockpaperscissors/paper/O0fq1v7s6qxN8o9L.png
# /kaggle/input/rockpaperscissors/paper/821xYeW8U0Iy6qVX.png
# /kaggle/input/rockpaperscissors/paper/RFXW2X1DlH7xboth.png
# /kaggle/input/rockpaperscissors/paper/ZveWRNmdKejc1c4w.png
# /kaggle/input/rockpaperscissors/paper/zb6wXq49QppiS9sf.png
# /kaggle/input/rockpaperscissors/paper/Af7KstxKjdhzUQyk.png
# /kaggle/input/rockpaperscissors/paper/aINwMVFw8UopgTOm.png
# /kaggle/input/rockpaperscissors/paper/w3fJMYnDDxw5q00K.png
# /kaggle/input/rockpaperscissors/paper/Ea6A81oe4Ria2MW3.png
# /kaggle/input/rockpaperscissors/paper/KHfp6LJDEhqbcomR.png
# /kaggle/input/rockpaperscissors/paper/UVuauoFm9Pk5JJre.png
# /kaggle/input/rockpaperscissors/paper/rffdDFsMVDDkn32c.png
# /kaggle/input/rockpaperscissors/paper/oTQjuZyEM7y9MlNJ.png
# /kaggle/input/rockpaperscissors/paper/mkUctpckc3vjOwKa.png
# /kaggle/input/rockpaperscissors/paper/sAEYBhcNfJgAZTD6.png
# /kaggle/input/rockpaperscissors/paper/3JN7OPsnxDBpcVeD.png
# /kaggle/input/rockpaperscissors/paper/EVtIRpfQ2ys2A3ag.png
# /kaggle/input/rockpaperscissors/paper/H8n0niVYdIGNGE0d.png
# /kaggle/input/rockpaperscissors/paper/FmDdvclwy9Wc1zfc.png
# /kaggle/input/rockpaperscissors/paper/qs7Zi0icFErU0fsZ.png
# /kaggle/input/rockpaperscissors/paper/C0WynzBAhXQGSywJ.png
# /kaggle/input/rockpaperscissors/paper/Gc4hUsoFAQBdulGg.png
# /kaggle/input/rockpaperscissors/paper/PZrfX01MvfB3oeyB.png
# /kaggle/input/rockpaperscissors/paper/ib30bLCbBl0mKWko.png
# /kaggle/input/rockpaperscissors/paper/BoXJ7o2SeSRRfuAH.png
# /kaggle/input/rockpaperscissors/paper/eBjRjXUIy7fpUaRy.png
# /kaggle/input/rockpaperscissors/paper/ISW7mRK3Wu6ik0eH.png
# /kaggle/input/rockpaperscissors/paper/tUAXecVWvaYBm4s4.png
# /kaggle/input/rockpaperscissors/paper/8vCpdCGSnX8CopJJ.png
# /kaggle/input/rockpaperscissors/paper/eaOtD5yLQHTuFTz3.png
# /kaggle/input/rockpaperscissors/paper/CbiqUiChqkXHb8jk.png
# /kaggle/input/rockpaperscissors/paper/YEGCpdShhdOdneq4.png
# /kaggle/input/rockpaperscissors/paper/v6Ypsa9vPurMnl20.png
# /kaggle/input/rockpaperscissors/paper/x3z3E6Z2qsmW8TaH.png
# /kaggle/input/rockpaperscissors/paper/gVd3f9CZNll3QS8l.png
# /kaggle/input/rockpaperscissors/paper/bTurr7qf07hoPQu1.png
# /kaggle/input/rockpaperscissors/paper/fMkDqtJgZAKa7dl5.png
# /kaggle/input/rockpaperscissors/paper/UmipL2kv9TdDdryZ.png
# /kaggle/input/rockpaperscissors/paper/jXhwHToky4rsswCO.png
# /kaggle/input/rockpaperscissors/paper/qWHWCHG7exZiCfdq.png
# /kaggle/input/rockpaperscissors/paper/8q4xxTvBVnXTRSQy.png
# /kaggle/input/rockpaperscissors/paper/8cUuoeM7qSsAGoOv.png
# /kaggle/input/rockpaperscissors/paper/b8dw4ZOgMTx2h1xI.png
# /kaggle/input/rockpaperscissors/paper/NnWvTxntBJ5mFY73.png
# /kaggle/input/rockpaperscissors/paper/XJlnAmd0Rb4GNRxm.png
# /kaggle/input/rockpaperscissors/paper/SjtYrw48VCBOLOQh.png
# /kaggle/input/rockpaperscissors/paper/Gv71lr2m5b9rBwPy.png
# /kaggle/input/rockpaperscissors/paper/JRZTPL2YQ6cfIMh9.png
# /kaggle/input/rockpaperscissors/paper/yYiQN5jZvkGqr6C5.png
# /kaggle/input/rockpaperscissors/paper/l7pEq6tQKyUNL3GN.png
# /kaggle/input/rockpaperscissors/paper/0t08v9bAaA0mXGCQ.png
# /kaggle/input/rockpaperscissors/paper/jqQlxUsZOssnmdWL.png
# /kaggle/input/rockpaperscissors/paper/tHitLUmmXOyChXOH.png
# /kaggle/input/rockpaperscissors/paper/37PRV3B9HxuUPkQr.png
# /kaggle/input/rockpaperscissors/paper/WOMFIvaWB3TEY6Gl.png
# /kaggle/input/rockpaperscissors/paper/0Og76sl5CJhbxWWx.png
# /kaggle/input/rockpaperscissors/paper/yB4dN62hOf4QeWGy.png
# /kaggle/input/rockpaperscissors/paper/V3Z0tEoM7Cq761eZ.png
# /kaggle/input/rockpaperscissors/paper/h4yYJuwG5dUXEY1B.png
# /kaggle/input/rockpaperscissors/paper/cXZYoC2Bu8SeHasE.png
# /kaggle/input/rockpaperscissors/paper/IxQ1CVKgnpiD0HfY.png
# /kaggle/input/rockpaperscissors/paper/5kJec3v9txvrAb4g.png
# /kaggle/input/rockpaperscissors/paper/3tyVmhojjwETaf1u.png
# /kaggle/input/rockpaperscissors/paper/U3XlUGS4C4YGpjGP.png
# /kaggle/input/rockpaperscissors/paper/lZkRVz5sifz7CD66.png
# /kaggle/input/rockpaperscissors/paper/KSueOZE0QWbJClvK.png
# /kaggle/input/rockpaperscissors/paper/lxWEYgTaWJSoYSiD.png
# /kaggle/input/rockpaperscissors/paper/oWI7JL85eXDhRFcV.png
# /kaggle/input/rockpaperscissors/paper/fPwDPzGZ5JeY0rb9.png
# /kaggle/input/rockpaperscissors/paper/ac0j8jCfz8hwpY0o.png
# /kaggle/input/rockpaperscissors/paper/KGiyDw5Ryx3WjjSZ.png
# /kaggle/input/rockpaperscissors/paper/f1aYiLdB5VC3L8Kk.png
# /kaggle/input/rockpaperscissors/paper/FT9FiK5l1lohzfxI.png
# /kaggle/input/rockpaperscissors/paper/qtYZl1WPMxaH5KQV.png
# /kaggle/input/rockpaperscissors/paper/Qxx5l8WCNBjMb5xI.png
# /kaggle/input/rockpaperscissors/paper/crYtjQcVKQjCAWYq.png
# /kaggle/input/rockpaperscissors/paper/ntumvg6vWpT6qIal.png
# /kaggle/input/rockpaperscissors/paper/fiX6rjBt5qHGMsjc.png
# /kaggle/input/rockpaperscissors/paper/Cto0fRvS0ns9lVrs.png
# /kaggle/input/rockpaperscissors/paper/DsaaqkHZUN3pmcwH.png
# /kaggle/input/rockpaperscissors/paper/cOHWfHkyo8sqWnpW.png
# /kaggle/input/rockpaperscissors/paper/UGHu0zv6pWOmgBWn.png
# /kaggle/input/rockpaperscissors/paper/et9oIiGQmAgwy7GK.png
# /kaggle/input/rockpaperscissors/paper/7YbjJFHGHPhJQFvE.png
# /kaggle/input/rockpaperscissors/paper/cUFSYeNYdnhRB6MD.png
# /kaggle/input/rockpaperscissors/paper/JbnPCQTbu7AS9jvo.png
# /kaggle/input/rockpaperscissors/paper/BfFGJgByTJnxADwA.png
# /kaggle/input/rockpaperscissors/paper/D9nbrQLDSgDMNh3G.png
# /kaggle/input/rockpaperscissors/paper/RmTijOM3U31zKnrY.png
# /kaggle/input/rockpaperscissors/paper/keyl4nDZLxLORnr3.png
# /kaggle/input/rockpaperscissors/paper/FJoRrTDakCLyWs75.png
# /kaggle/input/rockpaperscissors/paper/jl6AlteXSalbS3rG.png
# /kaggle/input/rockpaperscissors/paper/a45DJKHJdnCFhX5X.png
# /kaggle/input/rockpaperscissors/paper/ySmdq2LJmCBQatvr.png
# /kaggle/input/rockpaperscissors/paper/HyLg8tH9blwT6eVy.png
# /kaggle/input/rockpaperscissors/paper/aeVtGl2LQBr831P5.png
# /kaggle/input/rockpaperscissors/paper/84JL84r6Jcpp5Udi.png
# /kaggle/input/rockpaperscissors/paper/U5WsclDnMxnOTgGT.png
# /kaggle/input/rockpaperscissors/paper/oqJ2wJHOLMGGxdjF.png
# /kaggle/input/rockpaperscissors/paper/e96cq72UJTICTkE0.png
# /kaggle/input/rockpaperscissors/paper/6q2PxM8Kk16UxoMY.png
# /kaggle/input/rockpaperscissors/paper/oiJhtTsTDkiAcHeR.png
# /kaggle/input/rockpaperscissors/paper/pRZml1c5DSIzYVxA.png
# /kaggle/input/rockpaperscissors/paper/aICabYNb79bdS6Mu.png
# /kaggle/input/rockpaperscissors/paper/kdPdOkLZZW1UnOPw.png
# /kaggle/input/rockpaperscissors/paper/dyHfn1GBYIj195b5.png
# /kaggle/input/rockpaperscissors/paper/TmPdVzKg9yHUefja.png
# /kaggle/input/rockpaperscissors/paper/bddldJIGmQP5CSLD.png
# /kaggle/input/rockpaperscissors/paper/77rce5yVvVPIPmp8.png
# /kaggle/input/rockpaperscissors/paper/hWVwQVI74lc5zgyK.png
# /kaggle/input/rockpaperscissors/paper/fwnVVskCSNkB9LUL.png
# /kaggle/input/rockpaperscissors/paper/54xah1BB0YTQS3Ib.png
# /kaggle/input/rockpaperscissors/paper/wBUGgxpeb0gggcTx.png
# /kaggle/input/rockpaperscissors/paper/Zx5NMbS4YBf29guF.png
# /kaggle/input/rockpaperscissors/paper/45OQyZuXtfNCc8Rk.png
# /kaggle/input/rockpaperscissors/paper/VfIYGbOFu36N6MDw.png
# /kaggle/input/rockpaperscissors/paper/QUcJ1QclQwOY50vY.png
# /kaggle/input/rockpaperscissors/paper/lj8o8xy1TAOMQDaH.png
# /kaggle/input/rockpaperscissors/paper/AYfr1pZxmZyZaXWu.png
# /kaggle/input/rockpaperscissors/paper/qM0f6IJPDfLRpo1d.png
# /kaggle/input/rockpaperscissors/paper/cfCjmEcXysh0H52D.png
# /kaggle/input/rockpaperscissors/paper/gR2aEiEX8CzCtyBN.png
# /kaggle/input/rockpaperscissors/paper/9yGlnLxGtzq1gJti.png
# /kaggle/input/rockpaperscissors/paper/nb6CUTNhXBAmjFp9.png
# /kaggle/input/rockpaperscissors/paper/u5672IrPHHkppdEK.png
# /kaggle/input/rockpaperscissors/paper/27XFtQjjXQ8AP8Tl.png
# /kaggle/input/rockpaperscissors/paper/9v75qnx8zdeAAOq6.png
# /kaggle/input/rockpaperscissors/paper/xnLyw2TBZF8e2vcr.png
# /kaggle/input/rockpaperscissors/paper/HXxUlm3O2djcDgUR.png
# /kaggle/input/rockpaperscissors/paper/JQaNQ7LsPy3cY23Q.png
# /kaggle/input/rockpaperscissors/paper/04l5I8TqdzF9WDMJ.png
# /kaggle/input/rockpaperscissors/paper/HU7Q4utMI0vHMxlh.png
# /kaggle/input/rockpaperscissors/paper/MJAUydLSEPqZHwPz.png
# /kaggle/input/rockpaperscissors/paper/14K62H4KG1hg5qiJ.png
# /kaggle/input/rockpaperscissors/paper/o0CfvFooVIcHCGzO.png
# /kaggle/input/rockpaperscissors/paper/oKx22gb6XjI0aXHR.png
# /kaggle/input/rockpaperscissors/paper/VD4twqBeFDIHSovy.png
# /kaggle/input/rockpaperscissors/paper/9zuFLFklb0ibEelE.png
# /kaggle/input/rockpaperscissors/paper/9giVcOVtFf85mQZd.png
# /kaggle/input/rockpaperscissors/paper/ZtLFRBgHAyauXYW6.png
# /kaggle/input/rockpaperscissors/paper/TstngIvuLJt0GIze.png
# /kaggle/input/rockpaperscissors/paper/zVMOQFwVINs3dj8o.png
# /kaggle/input/rockpaperscissors/paper/6BIKQpfZEfQkCvrz.png
# /kaggle/input/rockpaperscissors/paper/owYHB2dx7ExdKxsR.png
# /kaggle/input/rockpaperscissors/paper/kmBByXdkwf5Vro8P.png
# /kaggle/input/rockpaperscissors/paper/OEFttKrmyc4bGb54.png
# /kaggle/input/rockpaperscissors/paper/qhhaVBNDIWDdNR2Y.png
# /kaggle/input/rockpaperscissors/paper/CIN4oPYURMvc4xTb.png
# /kaggle/input/rockpaperscissors/paper/TzhAea8QXqJwqpUY.png
# /kaggle/input/rockpaperscissors/paper/Ec6WrF6Soj4REPk7.png
# /kaggle/input/rockpaperscissors/paper/uHBQbKd9VTYWdctJ.png
# /kaggle/input/rockpaperscissors/paper/x8fNY0V8O2CJ9vaY.png
# /kaggle/input/rockpaperscissors/paper/2OCAZGNv2OEzgAwU.png
# /kaggle/input/rockpaperscissors/paper/axwcCc4rC8ySUtML.png
# /kaggle/input/rockpaperscissors/paper/sisDkUJdIN7AkgTV.png
# /kaggle/input/rockpaperscissors/paper/nPEUpKKphLYH3Bjy.png
# /kaggle/input/rockpaperscissors/paper/FEdPo8Z0t3bB1hHC.png
# /kaggle/input/rockpaperscissors/paper/HTSIUeIA1IQrHtHu.png
# /kaggle/input/rockpaperscissors/paper/UvFHqrnEwsrs6MgC.png
# /kaggle/input/rockpaperscissors/paper/jZe5ePOjxcQEJitP.png
# /kaggle/input/rockpaperscissors/paper/vHbB53ZFtZoNcvAM.png
# /kaggle/input/rockpaperscissors/paper/IlrxPx0XNL2QslmW.png
# /kaggle/input/rockpaperscissors/paper/ClP1hwm5k2IQsG1B.png
# /kaggle/input/rockpaperscissors/paper/1Tt9U9SzrOm98Xtw.png
# /kaggle/input/rockpaperscissors/paper/50Wjlq1jW7o3wcl8.png
# /kaggle/input/rockpaperscissors/paper/dmT5g2m3meABNfCJ.png
# /kaggle/input/rockpaperscissors/paper/4hcthlc3eCByBJFh.png
# /kaggle/input/rockpaperscissors/paper/7ZGsbIMypDIEZxR0.png
# /kaggle/input/rockpaperscissors/paper/L2oIlMxDTToJYUvV.png
# /kaggle/input/rockpaperscissors/paper/eW9ezZkV7Jxu1BEk.png
# /kaggle/input/rockpaperscissors/paper/ocaU2HmemX7rmjm0.png
# /kaggle/input/rockpaperscissors/paper/FVEAFUE9uhfJPi2f.png
# /kaggle/input/rockpaperscissors/paper/JFOcfFSm3Ul0Xkha.png
# /kaggle/input/rockpaperscissors/paper/Lui3J5YhKgMvk673.png
# /kaggle/input/rockpaperscissors/paper/XOWPFbuwpaJaEv9o.png
# /kaggle/input/rockpaperscissors/paper/9hKJu3ZMso4Qbtfh.png
# /kaggle/input/rockpaperscissors/paper/qVqPFRhMJXPFh8Yb.png
# /kaggle/input/rockpaperscissors/paper/9GnoYJhsreNoV2Wn.png
# /kaggle/input/rockpaperscissors/paper/TnoLyTMw8xPdz0ck.png
# /kaggle/input/rockpaperscissors/paper/FqTkhXfEVeaGHReH.png
# /kaggle/input/rockpaperscissors/paper/AtfMvZ19yfJJZapD.png
# /kaggle/input/rockpaperscissors/paper/7UoLr02FuYuLrJxz.png
# /kaggle/input/rockpaperscissors/paper/xyFhBLzUNatOchjM.png
# /kaggle/input/rockpaperscissors/paper/AMewmfMVCnLfbuNr.png
# /kaggle/input/rockpaperscissors/paper/yhXsHSeStA2dharc.png
# /kaggle/input/rockpaperscissors/paper/p2Y8kJZKuaHvM4dk.png
# /kaggle/input/rockpaperscissors/paper/9szmJOWlXxEbjDGV.png
# /kaggle/input/rockpaperscissors/paper/4fCqIVTEuFLsQMaZ.png
# /kaggle/input/rockpaperscissors/paper/c4FpTJmUl8wtm4n3.png
# /kaggle/input/rockpaperscissors/rock/qUjyvBdP04lUmBkl.png
# /kaggle/input/rockpaperscissors/rock/7YpH9C6XA1GIbSum.png
# /kaggle/input/rockpaperscissors/rock/ON7ALRXFwvKHbBPL.png
# /kaggle/input/rockpaperscissors/rock/2UaJz6Z3xJv3WX9h.png
# /kaggle/input/rockpaperscissors/rock/HWvrWXLQywNe1aCF.png
# /kaggle/input/rockpaperscissors/rock/ZM4bG569OHTj1XMT.png
# /kaggle/input/rockpaperscissors/rock/Zz52yCODsLplv7rK.png
# /kaggle/input/rockpaperscissors/rock/qnvJFE0EKgfw4xr8.png
# /kaggle/input/rockpaperscissors/rock/yAKYvpfUMYbJhbDP.png
# /kaggle/input/rockpaperscissors/rock/5G0hCO6RJXNyxcgV.png
# /kaggle/input/rockpaperscissors/rock/YmNXS0VhjQjldK3P.png
# /kaggle/input/rockpaperscissors/rock/SNEJ1wGU1s9Dm3I1.png
# /kaggle/input/rockpaperscissors/rock/FFAcRoW2ejkNNheZ.png
# /kaggle/input/rockpaperscissors/rock/WB7EanJC16YLgogF.png
# /kaggle/input/rockpaperscissors/rock/KQqIoVT62pLqhEGR.png
# /kaggle/input/rockpaperscissors/rock/R0j5MW4t8SU59u7x.png
# /kaggle/input/rockpaperscissors/rock/UDjD30Rke7seRcaD.png
# /kaggle/input/rockpaperscissors/rock/BYoDUgGsCMmAIF9I.png
# /kaggle/input/rockpaperscissors/rock/LF4yf48q3qRLLZNS.png
# /kaggle/input/rockpaperscissors/rock/5QHZzfwp2xJXckQb.png
# /kaggle/input/rockpaperscissors/rock/rit0UhP5HizIFoJA.png
# /kaggle/input/rockpaperscissors/rock/DEX2gmMwS3fxdi23.png
# /kaggle/input/rockpaperscissors/rock/Mhco9qeEh5TV83cQ.png
# /kaggle/input/rockpaperscissors/rock/Q7dUVly6sK3jyeMM.png
# /kaggle/input/rockpaperscissors/rock/Zyzp7nBCojgQeCZs.png
# /kaggle/input/rockpaperscissors/rock/m7OF0PiEJCUJyf6K.png
# /kaggle/input/rockpaperscissors/rock/2vwLOZSd8FCXbuck.png
# /kaggle/input/rockpaperscissors/rock/BsWasfK2PdoRNEDw.png
# /kaggle/input/rockpaperscissors/rock/H4DhPewFGkdWrc4A.png
# /kaggle/input/rockpaperscissors/rock/1MOm36DHK0R8OfIC.png
# /kaggle/input/rockpaperscissors/rock/KKYleXVUgi0h0np4.png
# /kaggle/input/rockpaperscissors/rock/BOswKcczxw8dC4kY.png
# /kaggle/input/rockpaperscissors/rock/rZ3CYuMZgTELnLxc.png
# /kaggle/input/rockpaperscissors/rock/QM8un28uGzplAkrb.png
# /kaggle/input/rockpaperscissors/rock/cY3jY96VetFq6Ayp.png
# /kaggle/input/rockpaperscissors/rock/O3ko4JxjCkdULELr.png
# /kaggle/input/rockpaperscissors/rock/tZFZV6hmUogDBeMl.png
# /kaggle/input/rockpaperscissors/rock/nLGBKJAhRNQqPFrT.png
# /kaggle/input/rockpaperscissors/rock/3Umm2S8TUyEpkbCY.png
# /kaggle/input/rockpaperscissors/rock/pU5fol2HJ1fxobLd.png
# /kaggle/input/rockpaperscissors/rock/BTcHjuerLAYWzx8S.png
# /kaggle/input/rockpaperscissors/rock/O5iExVmt45IRGquU.png
# /kaggle/input/rockpaperscissors/rock/FF2mNwRujDxzozUQ.png
# /kaggle/input/rockpaperscissors/rock/srlcv9vYJ9c9OUsC.png
# /kaggle/input/rockpaperscissors/rock/MwjRfqp6Gnh4vHI8.png
# /kaggle/input/rockpaperscissors/rock/cJOgpmKKBSPdPSeD.png
# /kaggle/input/rockpaperscissors/rock/02vG75hQW9Vp4oTl.png
# /kaggle/input/rockpaperscissors/rock/HnWLgtGVbnoPAaMK.png
# /kaggle/input/rockpaperscissors/rock/9sJrWSSurvaNb8FW.png
# /kaggle/input/rockpaperscissors/rock/91nHRDpe6EROWOyY.png
# /kaggle/input/rockpaperscissors/rock/43pApTDJOff5Fy62.png
# /kaggle/input/rockpaperscissors/rock/Aa9hY8wo2ixaUNKH.png
# /kaggle/input/rockpaperscissors/rock/DXlFk9LGWpbBewq2.png
# /kaggle/input/rockpaperscissors/rock/ZWKMxS1Yoa5ZvkOz.png
# /kaggle/input/rockpaperscissors/rock/DBvjNfYD7dv2f3gw.png
# /kaggle/input/rockpaperscissors/rock/Bm9hYmhGUGmKxDwK.png
# /kaggle/input/rockpaperscissors/rock/PYmGQFC1zj7mP3vh.png
# /kaggle/input/rockpaperscissors/rock/smfqjL7LuLnrPqo1.png
# /kaggle/input/rockpaperscissors/rock/cfyxwMjZmO6RYzLq.png
# /kaggle/input/rockpaperscissors/rock/zdNuxse3BvJK3s6Q.png
# /kaggle/input/rockpaperscissors/rock/1BqjHe5igJAgUjiN.png
# /kaggle/input/rockpaperscissors/rock/bX0QhJtFkkDn1bEw.png
# /kaggle/input/rockpaperscissors/rock/KtMqF92CMvQOIRrO.png
# /kaggle/input/rockpaperscissors/rock/zihL322yBqQvYvhE.png
# /kaggle/input/rockpaperscissors/rock/0NDYNEoDui7o64gU.png
# /kaggle/input/rockpaperscissors/rock/yF6HU2xSYYVTtH91.png
# /kaggle/input/rockpaperscissors/rock/BMet9oI6hmx1zdc9.png
# /kaggle/input/rockpaperscissors/rock/Gyq9GJFTfF1vvOZ8.png
# /kaggle/input/rockpaperscissors/rock/r0xQoW6iQbPig3jf.png
# /kaggle/input/rockpaperscissors/rock/5yHTRIIDcdrXqMYJ.png
# /kaggle/input/rockpaperscissors/rock/iaEybTdfnL0RoU9I.png
# /kaggle/input/rockpaperscissors/rock/U3EwYhdeoTjy3xBf.png
# /kaggle/input/rockpaperscissors/rock/QO4ebj2KlmPIU1Eo.png
# /kaggle/input/rockpaperscissors/rock/2HSPQEteONUjEXAF.png
# /kaggle/input/rockpaperscissors/rock/IoVOalbQe90ghv9U.png
# /kaggle/input/rockpaperscissors/rock/7Dh4gBDJVdP9tTLr.png
# /kaggle/input/rockpaperscissors/rock/5nKDkVzIMQWmtReM.png
# /kaggle/input/rockpaperscissors/rock/724DhutGELMHY1uD.png
# /kaggle/input/rockpaperscissors/rock/IQNb5XBjdbYa7A2W.png
# /kaggle/input/rockpaperscissors/rock/JXD8WyY4cQoEyvtU.png
# /kaggle/input/rockpaperscissors/rock/QF1S0sqb6YGe4GNP.png
# /kaggle/input/rockpaperscissors/rock/2nSUlcvPf1DOCo1j.png
# /kaggle/input/rockpaperscissors/rock/UjbgpVjrwzH0XvuD.png
# /kaggle/input/rockpaperscissors/rock/NQxWkhRHMkt2GrpB.png
# /kaggle/input/rockpaperscissors/rock/fjPydEfNWCvgobYu.png
# /kaggle/input/rockpaperscissors/rock/94oKRQFyit6SANlq.png
# /kaggle/input/rockpaperscissors/rock/TIm7htC6BXzkOitR.png
# /kaggle/input/rockpaperscissors/rock/cWKDIx5D1KB0zqjF.png
# /kaggle/input/rockpaperscissors/rock/LzPap5344J7kKj2P.png
# /kaggle/input/rockpaperscissors/rock/7NqXwATGidLt6kZY.png
# /kaggle/input/rockpaperscissors/rock/how0vUOltuU1m495.png
# /kaggle/input/rockpaperscissors/rock/yhdKczrnPdXbTjZc.png
# /kaggle/input/rockpaperscissors/rock/1WuMUpzupKs67q29.png
# /kaggle/input/rockpaperscissors/rock/gtVEm7JEdr0wE1ip.png
# /kaggle/input/rockpaperscissors/rock/T0Ac7jx8YlCdhjXB.png
# /kaggle/input/rockpaperscissors/rock/5sdSnAPfphSzXjWu.png
# /kaggle/input/rockpaperscissors/rock/9buKAwFejr8MhkAF.png
# /kaggle/input/rockpaperscissors/rock/Jg78GVOKbbyQchWq.png
# /kaggle/input/rockpaperscissors/rock/WRIlJop0nm7zZfg3.png
# /kaggle/input/rockpaperscissors/rock/gc8jqxVapG2o8ol1.png
# /kaggle/input/rockpaperscissors/rock/EQDfrFWZluld6aKP.png
# /kaggle/input/rockpaperscissors/rock/r87DASz5okmR0fnI.png
# ...
# /kaggle/input/rockpaperscissors/scissors/tZ8TlcDUMWqENtfF.png
# /kaggle/input/rockpaperscissors/scissors/G3WzvjZXkizn9iK9.png
# /kaggle/input/rockpaperscissors/scissors/twG9gv5cSKwb2CqR.png
# /kaggle/input/rockpaperscissors/scissors/Pms0QO8IsSP02WTP.png
# /kaggle/input/rockpaperscissors/scissors/LHW5Ms4SEAGtveh5.png
# /kaggle/input/rockpaperscissors/scissors/2J7q0JbqJrjmZC05.png
# /kaggle/input/rockpaperscissors/scissors/XN42vZFFWvOwwrEb.png
# /kaggle/input/rockpaperscissors/scissors/ngrJl9cJoUVFdYwO.png
# /kaggle/input/rockpaperscissors/scissors/kUUKyIbaWlM3GgEs.png
# /kaggle/input/rockpaperscissors/scissors/ny4ARFjALtDxJqGg.png
# /kaggle/input/rockpaperscissors/scissors/MFG70ohG4iZ3xm3b.png
# /kaggle/input/rockpaperscissors/scissors/xOdLJOH2sxWkgRTS.png
# /kaggle/input/rockpaperscissors/scissors/qq6omTHIt2LwuAo0.png
# /kaggle/input/rockpaperscissors/scissors/wvySukQJa9DYOX8v.png
# /kaggle/input/rockpaperscissors/scissors/IZYmxHXE1DVHJfYm.png
# /kaggle/input/rockpaperscissors/scissors/Eodp43S6sgfxeCST.png
# /kaggle/input/rockpaperscissors/scissors/6TMYdUMhaEWHQOcc.png
# /kaggle/input/rockpaperscissors/scissors/ZCr3PjDcttbKRAAW.png
# /kaggle/input/rockpaperscissors/scissors/Vn5KkLfrFuLeRyKZ.png
# /kaggle/input/rockpaperscissors/scissors/NInKk7uh3vNRuwCm.png
# /kaggle/input/rockpaperscissors/scissors/ainbAijlBiMxQcNq.png
# /kaggle/input/rockpaperscissors/scissors/r2sdyTijtdmySs6h.png
# /kaggle/input/rockpaperscissors/scissors/tZYSEIgQN7PZ31tk.png
# /kaggle/input/rockpaperscissors/scissors/CemUmBPmUpNgXfMC.png
# /kaggle/input/rockpaperscissors/scissors/fYsFOMTEQ0VIy1Ma.png
# /kaggle/input/rockpaperscissors/scissors/fnV8zv0atHjQzfhV.png
# /kaggle/input/rockpaperscissors/scissors/Egi7OpuV8V24C2LP.png
# /kaggle/input/rockpaperscissors/scissors/rtrnZkXYASc50OOJ.png
# /kaggle/input/rockpaperscissors/scissors/kiUc9msxBC2UZJ5g.png
# /kaggle/input/rockpaperscissors/scissors/5QHP8zydBsbWyt4T.png
# /kaggle/input/rockpaperscissors/scissors/nHMXDFvdVQ8Vb0F7.png
# /kaggle/input/rockpaperscissors/scissors/RZpLPA2iKiZ2GXR9.png
# /kaggle/input/rockpaperscissors/scissors/pJix3Ef2BAOt7yAz.png
# /kaggle/input/rockpaperscissors/scissors/G6trRFSUGIeaQorS.png
# /kaggle/input/rockpaperscissors/scissors/2V5E7uHmAh9eK0qt.png
# /kaggle/input/rockpaperscissors/scissors/cLvjnABO9kFuwjP0.png
# /kaggle/input/rockpaperscissors/scissors/AgfZ2awwDPr3d50b.png
# /kaggle/input/rockpaperscissors/scissors/VNbhUgHmivsf9WeB.png
# /kaggle/input/rockpaperscissors/scissors/HGhHQ3uNh7XFl2ar.png
# /kaggle/input/rockpaperscissors/scissors/65PVbRzrpzfdu8nJ.png
# /kaggle/input/rockpaperscissors/scissors/R8yTHsEmwnN776s2.png
# /kaggle/input/rockpaperscissors/scissors/Gr3EpS7AO3KtWTz0.png
# /kaggle/input/rockpaperscissors/scissors/DlzjcfKNEmUSyBy7.png
# /kaggle/input/rockpaperscissors/scissors/XpFaeZAqFUqqJ85b.png
# /kaggle/input/rockpaperscissors/scissors/RtsIA3p963IFGi8t.png
# /kaggle/input/rockpaperscissors/scissors/kY0Q7raIkxwCCOk2.png
# /kaggle/input/rockpaperscissors/scissors/0Ug54ifXRqqlZS2Z.png
# /kaggle/input/rockpaperscissors/scissors/JjS0KakWxwXmg5Wi.png
# /kaggle/input/rockpaperscissors/scissors/yiOfEmSzPhjaYDwH.png
# /kaggle/input/rockpaperscissors/scissors/M8g1dW2y0mQxe3OR.png
# /kaggle/input/rockpaperscissors/scissors/Y803FUXqbDOwGm0K.png
# /kaggle/input/rockpaperscissors/scissors/V14OoL0RMpvwPptc.png
# /kaggle/input/rockpaperscissors/scissors/ismjaxPJzOizyqOx.png
# /kaggle/input/rockpaperscissors/scissors/W7ijVLyfVPL2msio.png
# /kaggle/input/rockpaperscissors/scissors/oxU5O3n839QvrOGu.png
# /kaggle/input/rockpaperscissors/scissors/8ei3rSl89D6W8Tav.png
# /kaggle/input/rockpaperscissors/scissors/67sMDIYRNxuVsQQ8.png
# /kaggle/input/rockpaperscissors/scissors/ta6G9KRgDwtvZsrJ.png
# /kaggle/input/rockpaperscissors/scissors/rgh4Zpx9TkORJIWe.png
# /kaggle/input/rockpaperscissors/scissors/3sHqqD2BAKmQp4dk.png
# /kaggle/input/rockpaperscissors/scissors/c9oqImbEKG7Ij1cO.png
# /kaggle/input/rockpaperscissors/scissors/K06meJWsLavqjfyX.png
# /kaggle/input/rockpaperscissors/scissors/sJtSZbQH0MF9U4oa.png
# /kaggle/input/rockpaperscissors/scissors/5p5Qjz4unC0KcWoL.png
# /kaggle/input/rockpaperscissors/scissors/kklrxqhAClWO5J80.png
# /kaggle/input/rockpaperscissors/scissors/IOa7xROJIqP2jRQE.png
# /kaggle/input/rockpaperscissors/scissors/FqutRcI9gGbZl8Gv.png
# /kaggle/input/rockpaperscissors/scissors/w1NflQUWVQmFdZdI.png
# /kaggle/input/rockpaperscissors/scissors/1jKhi65BPTLXnUI6.png
# /kaggle/input/rockpaperscissors/scissors/gK1XEsUjwJ5gDOSz.png
# /kaggle/input/rockpaperscissors/scissors/xXxXuQZdlW8ebxCN.png
# /kaggle/input/rockpaperscissors/scissors/P2mN2BN7A8eaYm1l.png
# /kaggle/input/rockpaperscissors/scissors/i0pYFjwidPeBL3je.png
# /kaggle/input/rockpaperscissors/scissors/9r4WuhdqPmffGmPA.png
# /kaggle/input/rockpaperscissors/scissors/533ZH0WCaiOZO0nL.png
# /kaggle/input/rockpaperscissors/scissors/YLqWJoGJOcnoAZim.png
# /kaggle/input/rockpaperscissors/scissors/2TAGoXw7yaK0bXBu.png
# /kaggle/input/rockpaperscissors/scissors/RTCZxs3LhwklhSKk.png
# /kaggle/input/rockpaperscissors/scissors/2EeIeEe1P0a0Fi9v.png
# /kaggle/input/rockpaperscissors/scissors/KcCGOFZoEMOitVPh.png
# /kaggle/input/rockpaperscissors/scissors/Bd18RfxcJr6O5n6j.png
# /kaggle/input/rockpaperscissors/scissors/dOgYDnySFw6fj21T.png
# /kaggle/input/rockpaperscissors/scissors/uRSLPvxdMFumUTl4.png
# /kaggle/input/rockpaperscissors/scissors/9C2CyZRK18hcyHSx.png
# /kaggle/input/rockpaperscissors/scissors/8AR7dUmrz9jcFrHu.png
# /kaggle/input/rockpaperscissors/scissors/a8DBHodNOhJCxQrN.png
# /kaggle/input/rockpaperscissors/scissors/6drquJLYR4bjZX2E.png
# /kaggle/input/rockpaperscissors/scissors/9ZqjWey4XHP94iRr.png
# /kaggle/input/rockpaperscissors/scissors/mViP022ujNQr6UX1.png
# /kaggle/input/rockpaperscissors/scissors/a6nlEYiU2vnnUcp3.png
# /kaggle/input/rockpaperscissors/scissors/GIFgGPzv7MykUgzM.png
# /kaggle/input/rockpaperscissors/scissors/DgzqzxG2Zr26s93Y.png
# /kaggle/input/rockpaperscissors/scissors/JZXTU0Cv6A2WPuf5.png
# /kaggle/input/rockpaperscissors/scissors/sVmVaYH9SUDDI6y4.png
# /kaggle/input/rockpaperscissors/scissors/hmu0D0hhHVAD8wXd.png
# /kaggle/input/rockpaperscissors/scissors/oNZAuH1gIa65iSMu.png
# /kaggle/input/rockpaperscissors/scissors/7jLYhf025vHEX7kp.png
# /kaggle/input/rockpaperscissors/scissors/n8R1AoBrBUeqH7wZ.png
# /kaggle/input/rockpaperscissors/scissors/PVsR1GzEGP3wznMy.png
# /kaggle/input/rockpaperscissors/scissors/Ea5uaRMj6JwEAEtn.png
# /kaggle/input/rockpaperscissors/scissors/44Hu6owS3pPqmyG1.png
# /kaggle/input/rockpaperscissors/scissors/HqB3HFyK3VvZha0Y.png
# /kaggle/input/rockpaperscissors/scissors/H9H5HhYMY6vhEUJ4.png
# /kaggle/input/rockpaperscissors/scissors/95NcnE0omOzXLqs3.png
# /kaggle/input/rockpaperscissors/scissors/caj9PiWZ2BenuxXF.png
# /kaggle/input/rockpaperscissors/scissors/F0440RDr6eKJusnY.png
# /kaggle/input/rockpaperscissors/scissors/6ZAZiGMRp4VD1hDD.png
# /kaggle/input/rockpaperscissors/scissors/KfZNOowxVhhRLrza.png
# /kaggle/input/rockpaperscissors/scissors/VaVPcDb7mPMQ1gHk.png
# /kaggle/input/rockpaperscissors/scissors/wJNyEIqVDFH8bx5h.png
# /kaggle/input/rockpaperscissors/scissors/g1gIEqOv6YDveleA.png
# /kaggle/input/rockpaperscissors/scissors/PJxEXjRb0K0Mpgsz.png
# /kaggle/input/rockpaperscissors/scissors/zyml8p6mHzWWJTyw.png
# /kaggle/input/rockpaperscissors/scissors/EwkiPoJwnH40BjKa.png
# /kaggle/input/rockpaperscissors/scissors/N6hnu1jJLEfigfYH.png
# /kaggle/input/rockpaperscissors/scissors/IzA79EWPoX9pRKhq.png
# /kaggle/input/rockpaperscissors/scissors/MdKQlVomcJJ6Z1GA.png
# /kaggle/input/rockpaperscissors/scissors/ntwoVP9pgUbs3LGq.png
# /kaggle/input/rockpaperscissors/scissors/tpIDNu7Hg6k1SZef.png
# /kaggle/input/rockpaperscissors/scissors/xQB1ghQm8FBFNtBX.png
# /kaggle/input/rockpaperscissors/scissors/itXNIVO7ghl2qja8.png
# /kaggle/input/rockpaperscissors/scissors/ik80sIT0Ao6APY3M.png
# /kaggle/input/rockpaperscissors/scissors/rg2UeHqmCL67Pl4o.png
# /kaggle/input/rockpaperscissors/scissors/oneWMcLqF5aVRqz8.png
# /kaggle/input/rockpaperscissors/scissors/hly8CYYf6AiQucXm.png
# /kaggle/input/rockpaperscissors/scissors/GacGc5Z89bSZ5IXG.png
# /kaggle/input/rockpaperscissors/scissors/EkArrGlCdj8NNPbu.png
# /kaggle/input/rockpaperscissors/scissors/vcEwRcuUMQ89i8on.png
# /kaggle/input/rockpaperscissors/scissors/PsPaUu1XDiYpp92z.png
# /kaggle/input/rockpaperscissors/scissors/p67xXnYGlchlu7pi.png
# /kaggle/input/rockpaperscissors/scissors/XyUSCoWQqR72pGt8.png
# /kaggle/input/rockpaperscissors/scissors/RhwmhtMcSeQ0DeIJ.png
# /kaggle/input/rockpaperscissors/scissors/LErff4WDwhjsYG8Z.png
# /kaggle/input/rockpaperscissors/scissors/TqrIZuWA1XJR0MEK.png
# /kaggle/input/rockpaperscissors/scissors/KMUCDyhYewIdDnvu.png
# /kaggle/input/rockpaperscissors/scissors/IBauM2TU1KmGhsfT.png
# /kaggle/input/rockpaperscissors/scissors/X04PclHUrXo1cF1d.png
# /kaggle/input/rockpaperscissors/scissors/jwdItCvoNRkssn6D.png
# /kaggle/input/rockpaperscissors/scissors/LZ7UTYEoDao1EcYX.png
# /kaggle/input/rockpaperscissors/scissors/JTbM7M5ZIxA7oFEX.png
# /kaggle/input/rockpaperscissors/scissors/z5l2JCxLM7igVya5.png
# /kaggle/input/rockpaperscissors/scissors/kzjICtBZVnwJrYeI.png
# /kaggle/input/rockpaperscissors/scissors/CiZDoU3BINzzruL8.png
# /kaggle/input/rockpaperscissors/scissors/qfwqUBajqgUWpW86.png
# /kaggle/input/rockpaperscissors/scissors/RhZBWRRTO5Uen1Yp.png
# /kaggle/input/rockpaperscissors/scissors/WCJ45vWIRykFDXkA.png
# /kaggle/input/rockpaperscissors/scissors/NSv28DjjZXJ8mvhi.png
# /kaggle/input/rockpaperscissors/scissors/dWIQvO3tVSLw4etp.png
# /kaggle/input/rockpaperscissors/scissors/JWz75J1U5sGr1FH2.png
# /kaggle/input/rockpaperscissors/scissors/ejrBEOeknHrk4kCi.png
# /kaggle/input/rockpaperscissors/scissors/nukdu4gV8vol1FY9.png
# /kaggle/input/rockpaperscissors/scissors/MfDDFjVkEdWKPi2X.png
# /kaggle/input/rockpaperscissors/scissors/46fOqpoVsNjc9m9m.png
# /kaggle/input/rockpaperscissors/scissors/5CzwWCDnxKOJz5T0.png
# /kaggle/input/rockpaperscissors/scissors/RrbEWg7xTBv2qa9q.png
# /kaggle/input/rockpaperscissors/scissors/G5iYVibCVfZW27jB.png
# /kaggle/input/rockpaperscissors/scissors/6ZoT4ZO8D4G74afj.png
# /kaggle/input/rockpaperscissors/scissors/8rqHdq10eHPzVV4N.png
# /kaggle/input/rockpaperscissors/scissors/znR0vgP11p6yX3nI.png
# /kaggle/input/rockpaperscissors/scissors/FmGfsSfUAyHzsiAO.png
# /kaggle/input/rockpaperscissors/scissors/dpmWj9s5ily8GuyY.png
# /kaggle/input/rockpaperscissors/scissors/MFlCOcvmOe3jejwy.png
# /kaggle/input/rockpaperscissors/scissors/Me6SACZZ4EYJLHbB.png
# /kaggle/input/rockpaperscissors/scissors/FSQhfK1gcYqm4O4W.png
# /kaggle/input/rockpaperscissors/scissors/itSX8Pe5BwSSbcEb.png
# /kaggle/input/rockpaperscissors/scissors/XEmNGqnMFMoeRQRi.png
# /kaggle/input/rockpaperscissors/scissors/NMWjLWPkXc8YmJTP.png
# /kaggle/input/rockpaperscissors/scissors/qoU2kq8bmOjMY5e0.png
# /kaggle/input/rockpaperscissors/scissors/h8GCEjkSpQjdUuZH.png
# /kaggle/input/rockpaperscissors/scissors/QnZhnT6KrmNd35VN.png
# /kaggle/input/rockpaperscissors/scissors/1wZUIsowmZRmESjh.png
# /kaggle/input/rockpaperscissors/scissors/st0riwaAOtBFhJfA.png
# /kaggle/input/rockpaperscissors/scissors/esPjow7BN3RXc4gk.png
# /kaggle/input/rockpaperscissors/scissors/s3L79HfHyX9tyTS0.png
# /kaggle/input/rockpaperscissors/scissors/ZPjzBZeu7RFCMj7A.png
# /kaggle/input/rockpaperscissors/scissors/VcyQqsyvtkuKXWWz.png
# /kaggle/input/rockpaperscissors/scissors/xfdYfkrgEZ2fuuck.png
# /kaggle/input/rockpaperscissors/scissors/DJQMlkIuVBNMoXMX.png
# /kaggle/input/rockpaperscissors/scissors/CmzQ1oRM0ei850Wl.png
# /kaggle/input/rockpaperscissors/scissors/Mwmjta6k9iqQKKd7.png
# /kaggle/input/rockpaperscissors/scissors/ASH8lCQK8VGgkfyG.png
# /kaggle/input/rockpaperscissors/scissors/FayATL4XRpv7AB0y.png
# /kaggle/input/rockpaperscissors/scissors/9YPMzKwEOWcIx1oN.png
# /kaggle/input/rockpaperscissors/scissors/oDhw5SDj3rprGmyc.png
# /kaggle/input/rockpaperscissors/scissors/CTbANISUvZMD2T4L.png
# /kaggle/input/rockpaperscissors/scissors/dFlxUAypUgfOZqoV.png
# /kaggle/input/rockpaperscissors/scissors/e8p8cRK4gABNoiaZ.png
# /kaggle/input/rockpaperscissors/scissors/mRlkMzgNq3PxHHe4.png
# /kaggle/input/rockpaperscissors/scissors/JOwOktLqjDF0qFIW.png
# /kaggle/input/rockpaperscissors/scissors/4X8TOCQTfCWnMfm2.png
# /kaggle/input/rockpaperscissors/scissors/Xghl7QyFQxkC7zNQ.png
# /kaggle/input/rockpaperscissors/scissors/BtUfOjTzw9EEvNHO.png
# /kaggle/input/rockpaperscissors/scissors/Em50Yggfyz815VUH.png
# /kaggle/input/rockpaperscissors/scissors/7SOrAw5PvJghnwuq.png
# /kaggle/input/rockpaperscissors/scissors/MPiImIdtqCEKxDbP.png
# /kaggle/input/rockpaperscissors/scissors/M5u2FmtXKSMtK8yN.png
# /kaggle/input/rockpaperscissors/scissors/zepzkaBk60xgpP3C.png
# /kaggle/input/rockpaperscissors/scissors/zV0yCNG0C9s4GId3.png
# /kaggle/input/rockpaperscissors/scissors/sWC2BZ7oeSzsCXva.png
# /kaggle/input/rockpaperscissors/scissors/fRMSey1LBvG1TRWj.png
# /kaggle/input/rockpaperscissors/scissors/VRUsuwjXjZtW1Kaj.png
# /kaggle/input/rockpaperscissors/scissors/GGQjHIWNHMjBHBsr.png
# /kaggle/input/rockpaperscissors/scissors/UTc5RnTVPMdKnVPL.png
# /kaggle/input/rockpaperscissors/scissors/KM8TqJbWqew79vPt.png
# /kaggle/input/rockpaperscissors/scissors/I17M0iKd7oKgMtDw.png
# /kaggle/input/rockpaperscissors/scissors/ttGVYechgB3WAlum.png
# /kaggle/input/rockpaperscissors/scissors/plCaKcxMczZTYQYV.png
# /kaggle/input/rockpaperscissors/scissors/CO4Xhg1dx5dmvwlo.png
# /kaggle/input/rockpaperscissors/scissors/OLq5gEcrMDGftxeG.png
# /kaggle/input/rockpaperscissors/scissors/e7wuzMq70FDcvaFr.png
# /kaggle/input/rockpaperscissors/scissors/fdVS2hjaLlbu5u8J.png
# /kaggle/input/rockpaperscissors/scissors/VOgDVSfapx23t5tA.png
# /kaggle/input/rockpaperscissors/scissors/yAEtN7WUvS5S1Cmy.png
# /kaggle/input/rockpaperscissors/scissors/dnXr5NzZKqzg8VgI.png
# /kaggle/input/rockpaperscissors/scissors/Ep0yJCcioRpgZquy.png
# /kaggle/input/rockpaperscissors/scissors/H7drJKmXJb6g6YxC.png
# /kaggle/input/rockpaperscissors/scissors/Wp5WNP9Enlm4zjhx.png
# /kaggle/input/rockpaperscissors/scissors/9tyrAAweW8qCI4st.png
# /kaggle/input/rockpaperscissors/scissors/WYOb0YuOVCMs7ebJ.png
# /kaggle/input/rockpaperscissors/scissors/evBSpeXRlbUu82CV.png
# /kaggle/input/rockpaperscissors/scissors/YaRYYDirKENPeJcS.png
# /kaggle/input/rockpaperscissors/scissors/xQL4A9bjTuJuFj5K.png
# /kaggle/input/rockpaperscissors/scissors/iXpTSeMxuDfhayJw.png
# /kaggle/input/rockpaperscissors/scissors/UAaPcdGxSdKJngGc.png
# /kaggle/input/rockpaperscissors/scissors/hzvSpM4olIqXfeVt.png
# /kaggle/input/rockpaperscissors/scissors/Osm4O4K7sdFOSiRk.png
# /kaggle/input/rockpaperscissors/scissors/2fxAdPTgrVIoITsL.png
# /kaggle/input/rockpaperscissors/scissors/1xkTkvyzmavV7lQ5.png
# /kaggle/input/rockpaperscissors/scissors/NfmReZcDjjo6EJ3z.png
# /kaggle/input/rockpaperscissors/scissors/xtv6VZ84IEFHd9pS.png
# /kaggle/input/rockpaperscissors/scissors/vLsE4fWvRdNXdkvb.png
# /kaggle/input/rockpaperscissors/scissors/gbGB4caRQYsV8ZcR.png
# /kaggle/input/rockpaperscissors/scissors/YI6MrQ5Fa7DXhcjr.png
# /kaggle/input/rockpaperscissors/scissors/gLvAPtEJW1Ff5KLX.png
# /kaggle/input/rockpaperscissors/scissors/ZcGYyQZWKP4EcVEz.png
# /kaggle/input/rockpaperscissors/scissors/svWW1IeCIfKmCxvY.png
# /kaggle/input/rockpaperscissors/scissors/gs2BzCeH7aDo8Lhs.png
# /kaggle/input/rockpaperscissors/scissors/WtS1aLhJK2FZpcEt.png
# /kaggle/input/rockpaperscissors/scissors/1lEpWTJDphkm3HdC.png
# /kaggle/input/rockpaperscissors/scissors/8K3rwVoAAjAqkkqq.png
# /kaggle/input/rockpaperscissors/scissors/QbAO4VZw7Jlcenou.png
# /kaggle/input/rockpaperscissors/scissors/bLJSE1dl7VbQCUF9.png
# /kaggle/input/rockpaperscissors/scissors/QjvKDUTFuGf7gAm4.png
# /kaggle/input/rockpaperscissors/scissors/1CXgK9fgGdSRggD9.png
# /kaggle/input/rockpaperscissors/scissors/CjjM6i1OEFaKcm6e.png
# /kaggle/input/rockpaperscissors/scissors/g6KeAGhgzo4NSYWc.png
# /kaggle/input/rockpaperscissors/scissors/poCFGCxA1Vb8ucxm.png
# /kaggle/input/rockpaperscissors/scissors/ZGPpmBaEH8F0qXzI.png
# /kaggle/input/rockpaperscissors/scissors/F4iIoT06hTWSuSs2.png
# /kaggle/input/rockpaperscissors/scissors/LiCKhA8ipxSqU9Fo.png
# /kaggle/input/rockpaperscissors/scissors/WQlZZHmfKvMFfUE8.png
# /kaggle/input/rockpaperscissors/scissors/GVxDgpt5p4FA2e6n.png
# /kaggle/input/rockpaperscissors/scissors/UmpmKO5O9ku8kBwj.png
# /kaggle/input/rockpaperscissors/scissors/DH7iguASbWIzzBnT.png
# /kaggle/input/rockpaperscissors/scissors/2M8LvUBGMOH1bsaz.png
# /kaggle/input/rockpaperscissors/scissors/wjpTy95PqKpcRg9o.png
# /kaggle/input/rockpaperscissors/scissors/ZKG6hW0U101PcEoo.png
# /kaggle/input/rockpaperscissors/scissors/jL3CMVgsLdWznnKe.png

# %%
import shutil
import random
import math
import numpy as np
import cv2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg19 import VGG19

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model

from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
shutil.rmtree('./output')

# %%
os.makedirs('./output')
os.makedirs('./output/train')
os.makedirs('./output/val')
os.makedirs('./output/test')
os.listdir('./output')
# Out:
# ['test', 'train', 'val']

# %%
os.listdir('/kaggle/input')

root_dir = '/kaggle/input'
folder1 = 'rockpaperscissors'
folder2 = 'rockpaperscissors/rps-cv-images'
classes = ['rock', 'paper', 'scissors']

# %%
for clss in classes:
    print('------------' + clss + '-------------')
    dirtry = root_dir + '/' + folder1 + '/' + clss
    print(dirtry)
    files = os.listdir(dirtry)
    np.random.shuffle(files)
    
    print(len(files))

    base_dir = './output'
    
    for folder in ['train','val','test']:
        target_dir = base_dir + '/' + folder
        os.makedirs(target_dir + '/' + clss)
        target_class = target_dir + '/' + clss
        print(target_class,os.listdir(target_dir))

        if folder == 'train':
            print('folder',folder,target_class)
            images_to_pass = files[: math.floor(0.8*len(files))]
            print('imgs in ',folder,' and ', target_class, '::', len(images_to_pass))
            for img in images_to_pass:
                img = dirtry + '/' + img
                shutil.copy(img, target_class)
        elif folder == 'val':
            print('folder',folder,target_class)
            images_to_pass = files[math.floor(0.8*len(files)) : math.floor(0.9*len(files))]
            print('imgs in ',folder,' and ', target_class, '::', len(images_to_pass))
            for img in images_to_pass:
                img = dirtry + '/' + img
                shutil.copy(img, target_class)
        else:
            print('folder',folder,target_class)
            images_to_pass = files[math.floor(0.9*len(files)):]
            print('imgs in ',folder,' and ', target_class, '::', len(images_to_pass))
            for img in images_to_pass:
                img = dirtry + '/' + img
                shutil.copy(img, target_class)
    
    
val_sum = 0
for res1 in os.listdir('./output/val'):
    link1 = './output/val/' + res1
    val_sum += len(os.listdir(link1))
    
train_sum = 0
for res2 in os.listdir('./output/train'):
    link2 = './output/train/' + res2
    train_sum += len(os.listdir(link2))
    
test_sum = 0
for res in os.listdir('./output/test'):
    link = './output/test/' + res
    test_sum += len(os.listdir(link))
    
print(train_sum, val_sum, test_sum)
# Out:
# ------------rock-------------
# /kaggle/input/rockpaperscissors/rock
# 726
# ./output/train/rock ['rock']
# folder train ./output/train/rock
# imgs in  train  and  ./output/train/rock :: 580
# ./output/val/rock ['rock']
# folder val ./output/val/rock
# imgs in  val  and  ./output/val/rock :: 73
# ./output/test/rock ['rock']
# folder test ./output/test/rock
# imgs in  test  and  ./output/test/rock :: 73
# ------------paper-------------
# /kaggle/input/rockpaperscissors/paper
# 712
# ./output/train/paper ['paper', 'rock']
# folder train ./output/train/paper
# imgs in  train  and  ./output/train/paper :: 569
# ./output/val/paper ['paper', 'rock']
# folder val ./output/val/paper
# imgs in  val  and  ./output/val/paper :: 71
# ./output/test/paper ['paper', 'rock']
# folder test ./output/test/paper
# imgs in  test  and  ./output/test/paper :: 72
# ------------scissors-------------
# /kaggle/input/rockpaperscissors/scissors
# 750
# ./output/train/scissors ['scissors', 'paper', 'rock']
# folder train ./output/train/scissors
# imgs in  train  and  ./output/train/scissors :: 600
# ./output/val/scissors ['scissors', 'paper', 'rock']
# folder val ./output/val/scissors
# imgs in  val  and  ./output/val/scissors :: 75
# ./output/test/scissors ['scissors', 'paper', 'rock']
# folder test ./output/test/scissors
# imgs in  test  and  ./output/test/scissors :: 75
# 1749 219 220

# %%
train_path = './output/train'
val_path = './output/val'
test_path = './output/test'

# %%
x_train=[]

for folder in os.listdir(train_path):
    sub_path=train_path+"/"+folder
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(224,224))
        x_train.append(img_arr)
        
x_val=[]

for folder in os.listdir(val_path):
    sub_path=val_path+"/"+folder
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(224,224))
        x_val.append(img_arr)
        
x_test=[]

for folder in os.listdir(test_path):
    sub_path=test_path+"/"+folder
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(224,224))
        x_test.append(img_arr)

# %%
train_x=np.array(x_train)
val_x=np.array(x_val)
test_x=np.array(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27/937305675.py in <module>
#       2 val_x=np.array(x_val)
#       3 test_x=np.array(x_test)
# ----> 4 train_x.shape, x_train.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')

val_set = val_datagen.flow_from_directory(val_path,
                                          target_size = (224, 224),
                                          batch_size = 32,
                                          class_mode = 'sparse')

test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'sparse')
# Out:
# Found 1749 images belonging to 3 classes.
# Found 219 images belonging to 3 classes.
# Found 220 images belonging to 3 classes.

# %%
train_y=training_set.classes
val_y=val_set.classes
test_y=test_set.classes

# %%
training_set.class_indices, val_set.class_indices, test_set.class_indices
train_y.shape, val_y.shape, test_y.shape
# Out:
# ((1749,), (219,), (220,))

# %%
IMAGE_SIZE = [224,224]
vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# 2022-11-15 15:48:47.678411: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
#do not train the pre-trained layers of VGG-19
for layer in vgg.layers:
    layer.trainable = False

# %%
x = Flatten()(vgg.output)

# %%
prediction = Dense(3, activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 20,099,651
# Trainable params: 75,267
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(
  loss='sparse_categorical_crossentropy',
  optimizer="adam",
  metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5)

# %%
# fit the model
history = model.fit(
  train_x,
  train_y,
  validation_data=(val_x,val_y),
  epochs=10,
  callbacks=[early_stop],
  batch_size=32,shuffle=True)
# Out:
# 2022-11-15 15:51:34.077770: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 55/55 [==============================] - 582s 11s/step - loss: 2.4512 - accuracy: 0.8902 - val_loss: 1.8124 - val_accuracy: 0.8950
# Epoch 2/10
# 36/55 [==================>...........] - ETA: 2:58 - loss: 1.2988 - accuracy: 0.9314

# %%
# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.savefig('vgg-acc-rps-1.png')
plt.show()

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.savefig('vgg-loss-rps-1.png')
plt.show()

# %%
model.evaluate(test_x,test_y,batch_size=32)

# %%
#predict
y_pred=model.predict(test_x)
y_pred=np.argmax(y_pred,axis=1)

#get classification report
print(classification_report(y_pred,test_y))

#get confusion matrix
print(confusion_matrix(y_pred,test_y))
